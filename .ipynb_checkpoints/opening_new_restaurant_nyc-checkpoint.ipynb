# %% [markdown]
# # Capstone Project: Opening New Restaurant in NYC
# #### Applied Data Science Capstone

# %% [markdown]
# ### Table of Contents
# 1. [Background](#background)
# * [Business Problem](#business_problem)
# * [Target Audience](#audience)
# * [Data Requirement & Sources](#data)
# * [Data Collection & Preprocessing](#data_preprocess)
# * [Modeling](#modeling)
# * [Analysis](#analysis)
# * [Conclusion](#conclusion)

# %% [markdown]
# ### 1. Background <a name="background"> </a>

# %% [markdown]
# New York City (NYC) is the most populous city in the United States (US) with <b>over 8 million population</b> spread over five boroughs, Brooklyn, Queens, Manhattan, Bronx, and Staten Island. It is well known as global capital of finance, media, and immigrant. NYC is also a global leader in entertainment, fashion, tourism, technology, education, arts, sports, politics, research, and many more industries. Many of the World’s most visited tourist attractions are located in NYC. Times Square and Broadway Theater District are few of them. <b>More than 62 million tourists visited in 2017</b>. You can find communities representing whole world, in fact more than 800 languages are spoken in NYC.
# ![image.png](attachment:image.png)
# <p>NYC is also the home of the World’s largest stock exchanges. Many of the World’s largest financial and media companies are based in NYC. Recently, new technology and biotechnology companies are growing very fast. In brief, NYC is a power house for every business sector you can imagine. Obviously, restaurant industry has huge opportunity in NYC. After all, the 8+ million New Yorkers and 62+ million tourists need to eat every single day with demands for every possible cuisine on the earth. There is no other better place to open a restaurant than NYC neighborhoods.</p>

# %% [markdown]
# ### 2. Business Problem <a name="business_problem"> </a>

# %% [markdown]
# <p>Being the most populous city in US and one of most visited cities in the world, is it easy to open a new restaurant successfully in NYC? Even though market for restaurant business is huge in NYC, there are already plenty of restaurants in popular neighborhoods serving every kind of cuisine from every corners of the world. The process of finding the best place for the new business is not as trivial as it may seem. It requires careful and thorough research and decision to find best possible real estate to give the new eatery best chance to succeed. It requires time, domain expertise, and capital.</p>
# <p>	So, the problem every new entrepreneur may face is <b>how to find the best location to open a new restaurant in NYC with ease, precision, and quickly so that the new business has best chance to succeed?</b></p>
# <p>There is a better solution for the new restaurant entrepreneurs and current restaurant owners who want to expand their business. The solution is machine learning models such as clustering. The main objective of this capstone is to develop a k-means clustering model and visualize the clusters in the NYC map by using NYC neighborhood datasets along with Foursquare API to help the prospective restaurant owners to select best possible NYC neighborhood for their new business quickly with greater precision. So, <b>this project will help simplify the tedious process of opening new restaurant saving the precious time for the restaurant owner.</b></p>

# %% [markdown]
# ### 3. Target Audience <a name="audience"></a>

# %% [markdown]
# ### 4. Data Requirements & Sources <a name="data"></a>

# %% [markdown]
# #### Requirements:
# <p>To build the machine learning models, first we need the datasets representative of the business problem. For this project, we are going to use following datasets:</p>
#
# *  New York City neighborhood dataset which contain list of neighborhood names and their geographic coordinates in five boroughs, Brooklyn, Bronx, Manhattan, Queens, and Staten Island. This dataset defines the scope of this project which is the neighborhoods in five boroughs of NYC. This dataset also provides the geographic coordinates, latitude and longitude in order to plot the locations of the neighborhoods on the NYC map.
#
# * Census Demographics at NYC Neighborhood Tabulation Area (NTA) dataset. This dataset contains 2010 census population of NYC neighborhoods and it will be used to plot the population density of the neighborhoods on the NYC map. This is obviously very helpful to make decision to start new restaurant. After all, restaurants are for feeding the hungry customers and larger the population more the hungry customers the restaurant is going to get.
#
# * NYC crime dataset based on NYPD complaint dataset. This dataset contains all valid felony, misdemeanor, and violation crimes reported the New York City Police Department in 2019 and the geographic location of the crimes. So, we will plot the crime locations on the NYC map. This will add an additional factor to determine whether the neighborhood is good for the new restaurant.
#
# * Venue dataset returned by the Foursquare API based on the NYC neighborhoods dataset. This data will be used to perform clustering of the NYC neighborhoods based on the most popular venues and the restaurants in the neighborhoods. By clustering the neighborhoods based on the most popular venues and restaurants, it will help make decision if the neighborhood is good for food related venues or if the neighborhood is already too saturated for food related venues.
#
# #### Sources:
#
# * https://cocl.us/new_york_dataset contains 306 New York City neighborhood names with their geographic coordinates spread over five boroughs. The data will be retrieved using the python package requests as json file and will be converted into pandas dataframe with the borough and neighborhood names along with their latitude and longitude as the columns.
#
# * https://data.ny.gov/resource/rnsn-acs2.json contains 2010 census population of NYC neighborhoods in the five boroughs. This data will also be retrieved using requests package and convert into pandas dataframe.
#
# * https://data.cityofnewyork.us/api/views/93vf-i5bz/rows.json?accessType=DOWNLOAD contains area of NYC neighborhoods in all boroughs.
#
# * https://data.cityofnewyork.us/api/views/5uac-w243/rows.json?accessType=DOWNLOAD contains the crimes reported the New York City Police Department in 2019. This data will also be retrieved and converted similarly as other datasets.
#
# * https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={} is Foursquare API and it will be called for every NYC neighborhoods.

# %% [markdown]
# ### 4. Data Collection & Preprocessing <a name="data_preprocess"></a>

# %%
import pandas as pd
import numpy as np
import requests
import folium

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
#Haversine formula

# %% [markdown]
# #### New York City neighborhood dataset

# %%
nyc = requests.get('https://cocl.us/new_york_dataset').json()

# %%
nyc.keys()
# Out:
# dict_keys(['type', 'totalFeatures', 'features', 'crs', 'bbox'])

# %%
nyc['features'][0].keys()
# Out:
# dict_keys(['type', 'id', 'geometry', 'geometry_name', 'properties'])

# %%
nyc['features'][0]['properties']
# Out:
# {'name': 'Wakefield',
#  'stacked': 1,
#  'annoline1': 'Wakefield',
#  'annoline2': None,
#  'annoline3': None,
#  'annoangle': 0.0,
#  'borough': 'Bronx',
#  'bbox': [-73.84720052054902,
#   40.89470517661,
#   -73.84720052054902,
#   40.89470517661]}

# %%
nyc_df = nyc['features']
dict_list = []
for data in nyc_df:
    borough = data['properties']['borough'] 
    n_name = data['properties']['name']
        
    n_latlng = data['geometry']['coordinates']
    n_lat = n_latlng[1]
    n_lng = n_latlng[0]
    # for consistency, all column names will be lowercase.
    dict_list.append({'borough': borough,
                     'neighborhood': n_name,
                     'latitude': n_lat,
                     'longitude': n_lng})
nyc_df = pd.DataFrame(dict_list)

# %%
nyc_df.head()
# Out:
#   borough   latitude  longitude neighborhood
# 0   Bronx  40.894705 -73.847201    Wakefield
# 1   Bronx  40.874294 -73.829939   Co-op City
# 2   Bronx  40.887556 -73.827806  Eastchester
# 3   Bronx  40.895437 -73.905643    Fieldston
# 4   Bronx  40.890834 -73.912585    Riverdale

# %%
print('Total Borough: {}  & Total neighborhoods: {}'.format(
        len(nyc_df.borough.unique()), len(nyc_df.neighborhood.unique())))
# Out:
# Total Borough: 5  & Total neighborhoods: 302

# %%
gp=nyc_df.groupby('neighborhood').count()
gp.loc[gp.borough == 2]
# Out:
#               borough  latitude  longitude
# neighborhood
# Bay Terrace         2         2          2
# Chelsea             2         2          2
# Murray Hill         2         2          2
# Sunnyside           2         2          2

# %% [markdown]
# #### NYC Neighborhoods 2010 population

# %%
nyc_pop_json = requests.get('https://data.ny.gov/resource/rnsn-acs2.json').json()

# %%
nyc_pop = pd.io.json.json_normalize(nyc_pop_json)

# %%
nyc_pop.columns
# Out:
# Index(['geographic_area_2010_census_fips_county_code',
#        'geographic_area_borough',
#        'geographic_area_neighborhood_tabulation_area_nta_code',
#        'geographic_area_neighborhood_tabulation_area_nta_name',
#        'total_population_2000_number', 'total_population_2010_number',
#        'total_population_change_2000_2010_number',
#        'total_population_change_2000_2010_percent'],
#       dtype='object')

# %%
nyc_pop_df = nyc_pop.iloc[:,[0,1,2,3,5]]
nyc_pop_df.columns = ['fips_code', 'borough','nta_code', 'neighborhood', 'population']
nyc_pop_df.head()
# Out:
#   fips_code borough nta_code                     neighborhood population
# 0         5   Bronx     BX01               Claremont-Bathgate      31078
# 1         5   Bronx     BX03  Eastchester-Edenwald-Baychester      34517
# 2         5   Bronx     BX05       Bedford Park-Fordham North      54415
# 3         5   Bronx     BX06                          Belmont      27378
# 4         5   Bronx     BX07                        Bronxdale      35538

# %%
len(nyc_pop_df.neighborhood.unique()), len(nyc_pop_df.nta_code.unique())
# Out:
# (196, 196)

# %%
nyc_pop_df.borough.unique()
# Out:
# array(['Bronx', 'Brooklyn', 'Manhattan', 'Queens', 'Staten Island',
#        "*Neighborhood Tabulation Areas, or NTAs, are aggregations of census tracts that are subsets of New York City's 55 Public Use Microdata Areas (PUMAs). ",
#        'Primarily due to these constraints, NTA boundaries and their associated names may not definitively represent neighborhoods.'],
#       dtype=object)

# %%
nyc_pop_df.fips_code.unique()
# Out:
# array(['5', '47', '61', '81', '85', nan], dtype=object)

# %%
len(nyc_pop_df.loc[nyc_pop_df.borough == 'Manhattan'])
# Out:
# 29

# %%
len(nyc_df.loc[nyc_df.borough == 'Manhattan'])
# Out:
# 40

# %% [markdown]
# #### NYC Neighborhoods area

# %%
nyc_area_json = requests.get('https://data.cityofnewyork.us/api/views/93vf-i5bz/rows.json?accessType=DOWNLOAD').json()

# %%
rows = []
rows_num = len(nyc_area_json['data'])
for row in range(rows_num):
    rows.append(np.array(nyc_area_json['data'][row])[[8,12]])
    
nyc_area_df = pd.DataFrame(rows, columns = ['geom','nta_code'])

# %%
# nyc_area_json['data'][0]

# %%
len(nyc_pop_df.loc[nyc_pop_df.borough == 'Bronx'])
# Out:
# 38

# %%
nyc_area_df.head()
# Out:
#                                                 geom nta_code
# 0  MULTIPOLYGON (((-73.94732672160586 40.62916656...     BK43
# 1  MULTIPOLYGON (((-73.94193078816201 40.70072523...     BK75
# 2  MULTIPOLYGON (((-73.89138023380268 40.86170058...     BX40
# 3  MULTIPOLYGON (((-73.9760493559142 40.631275905...     BK88
# 4  MULTIPOLYGON (((-73.90855790522774 40.65209593...     BK96

# %%
len(nyc_area_df), len(nyc_area_df.nta_code.unique())
# Out:
# (195, 195)

# %%
nyc_area_df.iloc[0,0].split('(((')[1].split(',')[0]
# Out:
# '-73.94732672160586 40.62916656720947'

# %%
nyc_pop = pd.merge(nyc_pop_df, nyc_area_df, on = 'nta_code')

# %%
nyc_pop.head()
# Out:
#   fips_code borough nta_code                     neighborhood population  \
# 0         5   Bronx     BX01               Claremont-Bathgate      31078
# 1         5   Bronx     BX03  Eastchester-Edenwald-Baychester      34517
# 2         5   Bronx     BX05       Bedford Park-Fordham North      54415
# 3         5   Bronx     BX06                          Belmont      27378
# 4         5   Bronx     BX07                        Bronxdale      35538
#
#                                                 geom
# 0  MULTIPOLYGON (((-73.89038954009592 40.85468905...
# 1  MULTIPOLYGON (((-73.79322870948383 40.88282259...
# 2  MULTIPOLYGON (((-73.88362518063384 40.86725758...
# 3  MULTIPOLYGON (((-73.8830938237215 40.866602185...
# 4  MULTIPOLYGON (((-73.86137924069509 40.87133651...

# %%
lat = nyc_df.loc[0, 'latitude']
lng = nyc_df.loc[0, 'longitude']

# %%
# create map of New York using latitude and longitude values
map_newyork = folium.Map(location=[lat, lng], zoom_start=10)

# add markers to map
for lat, lng, b, n in zip(nyc_df['latitude'], nyc_df['longitude'], 
                                           nyc_df['borough'], nyc_df['neighborhood']):
    label = '{}, {}'.format(n, b)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_newyork)  
    
map_newyork
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### NYC Crime data reported to NYPD in 2019

# %%
crime_json = requests.get('https://data.cityofnewyork.us/api/views/5uac-w243/rows.json?accessType=DOWNLOAD').json()

# %%
[d['name'] for d in crime_json['meta']['view']['columns'][8:]]
# Out:
# ['CMPLNT_NUM',
#  'ADDR_PCT_CD',
#  'BORO_NM',
#  'CMPLNT_FR_DT',
#  'CMPLNT_FR_TM',
#  'CMPLNT_TO_DT',
#  'CMPLNT_TO_TM',
#  'CRM_ATPT_CPTD_CD',
#  'HADEVELOPT',
#  'HOUSING_PSA',
#  'JURISDICTION_CODE',
#  'JURIS_DESC',
#  'KY_CD',
#  'LAW_CAT_CD',
#  'LOC_OF_OCCUR_DESC',
#  'OFNS_DESC',
#  'PARKS_NM',
#  'PATROL_BORO',
#  'PD_CD',
#  'PD_DESC',
#  'PREM_TYP_DESC',
#  'RPT_DT',
#  'STATION_NAME',
#  'SUSP_AGE_GROUP',
#  'SUSP_RACE',
#  'SUSP_SEX',
#  'TRANSIT_DISTRICT',
#  'VIC_AGE_GROUP',
#  'VIC_RACE',
#  'VIC_SEX',
#  'X_COORD_CD',
#  'Y_COORD_CD',
#  'Latitude',
#  'Longitude',
#  'Lat_Lon',
#  'Zip Codes',
#  'Community Districts',
#  'Borough Boundaries',
#  'City Council Districts',
#  'Police Precincts']

# %%
rows = []
crime_num = len(crime_json['data'])
for row in range(crime_num):
    rows.append(crime_json['data'][row][8:])
crime_df = pd.DataFrame(rows)
crime_df = crime_df.iloc[:,[0, 2,13, 15,32,33,35]]
crime_df.columns = ['crime_id','borough', 'crime_level', 'crime_desc', 'latitue', 'longitude', 'zip_code']

# %%
crime_df.head()
# Out:
#     crime_id    borough  crime_level      crime_desc             latitue  \
# 0  314773184      BRONX       FELONY         ROBBERY  40.838026269000075
# 1  289837961  MANHATTAN  MISDEMEANOR   PETIT LARCENY  40.800334261000046
# 2  535744284   BROOKLYN       FELONY  FELONY ASSAULT   40.66983179600004
# 3  895678119      BRONX  MISDEMEANOR   PETIT LARCENY   40.87367103500002
# 4  299841674  MANHATTAN  MISDEMEANOR   PETIT LARCENY   40.76093528000007
#
#             longitude zip_code
# 0  -73.88168118799997    11269
# 1  -73.94565697199994    13093
# 2  -73.93937555099996    17615
# 3  -73.90801364899994    11272
# 4  -73.99452906599998    13094

# %% [markdown]
# #### Foursquare API for venues data

# %%
CLIENT_ID = 'FOB3MKIYUMLEZAF00B0YWFHKKZPGE2FT1L4GO1RPL4HD3NRS' # your Foursquare ID
CLIENT_SECRET = 'W3VRIBWFXKJDPR1PXLC1TQEJLT3VRKK2MJE15PLDI3M5E3KE' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
LIMIT = 100 # limit of number of venues returned by Foursquare API
radius = 500 # define radius

# %%
lat = nyc_df.loc[0, 'latitude'] # neighborhood latitude value
lng = nyc_df.loc[0, 'longitude'] # neighborhood longitude value

# %%
# create URL
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    lat, 
    lng, 
    radius, 
    LIMIT)
url # display URL
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=FOB3MKIYUMLEZAF00B0YWFHKKZPGE2FT1L4GO1RPL4HD3NRS&client_secret=W3VRIBWFXKJDPR1PXLC1TQEJLT3VRKK2MJE15PLDI3M5E3KE&v=20180605&ll=40.89470517661,-73.84720052054902&radius=500&limit=100'

# %%
results = requests.get(url).json()
results['response'].keys()
# Out:
# dict_keys(['suggestedFilters', 'headerLocation', 'headerFullLocation', 'headerLocationGranularity', 'totalResults', 'suggestedBounds', 'groups'])

# %%
for k in results['response'].keys():
    print(k, '---> ', results['response'][k])
    print('****************')
# Out:
# suggestedFilters --->  {'header': 'Tap to show:', 'filters': [{'name': 'Open now', 'key': 'openNow'}]}
# ****************
# headerLocation --->  Wakefield
# ****************
# headerFullLocation --->  Wakefield, Bronx
# ****************
# headerLocationGranularity --->  neighborhood
# ****************
# totalResults --->  10
# ****************
# suggestedBounds --->  {'ne': {'lat': 40.899205181110005, 'lng': -73.84125857127495}, 'sw': {'lat': 40.89020517211, 'lng': -73.8531424698231}}
# ****************
# groups --->  [{'type': 'Recommended Places', 'name': 'recommended', 'items': [{'reasons': {'count': 0, 'items': [{'summary': 'This spot is popular', 'type': 'general', 'reasonName': 'globalInteractionReason'}]}, 'venue': {'id': '4c537892fd2ea593cb077a28', 'name': 'Lollipops Gelato', 'location': {'address': '4120 Baychester Ave', 'crossStreet': 'Edenwald & Bussing Ave', 'lat': 40.894123150205274, 'lng': -73.84589162362325, 'labeledLatLngs': [{'label': 'display', 'lat': 40.894123150205274, 'lng': -73.84589162362325}], 'distance': 127, 'postalCode': '10466', 'cc': 'US', 'city': 'Bronx', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['4120 Baychester Ave (Edenwald & Bussing Ave)', 'Bronx, NY 10466', 'United States']}, 'categories': [{'id': '4bf58dd8d48988d1d0941735', 'name': 'Dessert Shop', 'pluralName': 'Dessert Shops', 'shortName': 'Desserts', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_', 'suffix': '.png'}, 'primary': True}], 'photos': {'count': 0, 'groups': []}}, 'referralId': 'e-0-4c537892fd2ea593cb077a28-0'}, {'reasons': {'count': 0, 'items': [{'summary': 'This spot is popular', 'type': 'general', 'reasonName': 'globalInteractionReason'}]}, 'venue': {'id': '4d6af9426107f04dedeb297a', 'name': 'Rite Aid', 'location': {'address': '4232 Baychester Ave', 'lat': 40.896649, 'lng': -73.8448461, 'labeledLatLngs': [{'label': 'display', 'lat': 40.896649, 'lng': -73.8448461}], 'distance': 293, 'postalCode': '10466', 'cc': 'US', 'city': 'Bronx', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['4232 Baychester Ave', 'Bronx, NY 10466', 'United States']}, 'categories': [{'id': '4bf58dd8d48988d10f951735', 'name': 'Pharmacy', 'pluralName': 'Pharmacies', 'shortName': 'Pharmacy', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_', 'suffix': '.png'}, 'primary': True}], 'photos': {'count': 0, 'groups': []}}, 'referralId': 'e-0-4d6af9426107f04dedeb297a-1'}, {'reasons': {'count': 0, 'items': [{'summary': 'This spot is popular', 'type': 'general', 'reasonName': 'globalInteractionReason'}]}, 'venue': {'id': '4c783cef3badb1f7e4244b54', 'name': 'Carvel Ice Cream', 'location': {'address': '1006 E 233rd St', 'lat': 40.890486685759605, 'lng': -73.84856772568665, 'labeledLatLngs': [{'label': 'display', 'lat': 40.890486685759605, 'lng': -73.84856772568665}], 'distance': 483, 'postalCode': '10466', 'cc': 'US', 'city': 'Bronx', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['1006 E 233rd St', 'Bronx, NY 10466', 'United States']}, 'categories': [{'id': '4bf58dd8d48988d1c9941735', 'name': 'Ice Cream Shop', 'pluralName': 'Ice Cream Shops', 'shortName': 'Ice Cream', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_', 'suffix': '.png'}, 'primary': True}], 'photos': {'count': 0, 'groups': []}}, 'referralId': 'e-0-4c783cef3badb1f7e4244b54-2'}, {'reasons': {'count': 0, 'items': [{'summary': 'This spot is popular', 'type': 'general', 'reasonName': 'globalInteractionReason'}]}, 'venue': {'id': '5d5f5044d0ae1c0008f043c3', 'name': 'Walgreens', 'location': {'address': '4232 Baychester Ave', 'crossStreet': 'Pitman', 'lat': 40.896687, 'lng': -73.84485, 'labeledLatLngs': [{'label': 'display', 'lat': 40.896687, 'lng': -73.84485}], 'distance': 296, 'postalCode': '10466', 'cc': 'US', 'city': 'Bronx', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['4232 Baychester Ave (Pitman)', 'Bronx, NY 10466', 'United States']}, 'categories': [{'id': '4bf58dd8d48988d10f951735', 'name': 'Pharmacy', 'pluralName': 'Pharmacies', 'shortName': 'Pharmacy', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_', 'suffix': '.png'}, 'primary': True}], 'photos': {'count': 0, 'groups': []}}, 'referralId': 'e-0-5d5f5044d0ae1c0008f043c3-3'}, {'reasons': {'count': 0, 'items': [{'summary': 'This spot is popular', 'type': 'general', 'reasonName': 'globalInteractionReason'}]}, 'venue': {'id': '4c81a91c51ada1cd87741510', 'name': 'Shell', 'location' ...
# ****************

# %%
len(results['response']['groups'])
# Out:
# 1

# %%
results['response']['groups'][0].keys()
# Out:
# dict_keys(['type', 'name', 'items'])

# %%
len(results['response']['groups'][0]["type"])
# Out:
# 18

# %%
results['response']['groups'][0]["name"]
# Out:
# 'recommended'

# %%
results['response']['groups'][0]["type"]
# Out:
# 'Recommended Places'

# %%
results['response']['groups'][0]["items"][0].keys()
# Out:
# dict_keys(['reasons', 'venue', 'referralId'])

# %%
len(results['response']['groups'][0]["items"])
# Out:
# 10

# %%
results['response']['groups'][0]["items"][0]['reasons']
# Out:
# {'count': 0,
#  'items': [{'summary': 'This spot is popular',
#    'type': 'general',
#    'reasonName': 'globalInteractionReason'}]}

# %%
results['response']['groups'][0]["items"][0]['venue'].keys()
# Out:
# dict_keys(['id', 'name', 'location', 'categories', 'photos'])

# %%
for k in results['response']['groups'][0]["items"][0]['venue'].keys():
    print(k, '=== ', results['response']['groups'][0]["items"][0]['venue'][k])
# Out:
# id ===  4c537892fd2ea593cb077a28
# name ===  Lollipops Gelato
# location ===  {'address': '4120 Baychester Ave', 'crossStreet': 'Edenwald & Bussing Ave', 'lat': 40.894123150205274, 'lng': -73.84589162362325, 'labeledLatLngs': [{'label': 'display', 'lat': 40.894123150205274, 'lng': -73.84589162362325}], 'distance': 127, 'postalCode': '10466', 'cc': 'US', 'city': 'Bronx', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['4120 Baychester Ave (Edenwald & Bussing Ave)', 'Bronx, NY 10466', 'United States']}
# categories ===  [{'id': '4bf58dd8d48988d1d0941735', 'name': 'Dessert Shop', 'pluralName': 'Dessert Shops', 'shortName': 'Desserts', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_', 'suffix': '.png'}, 'primary': True}]
# photos ===  {'count': 0, 'groups': []}

# %%
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    neighborhood_latitude, 
    neighborhood_longitude, 
    radius, 
    LIMIT)
url # display URL

# %% [markdown]
# # NYC NTA

# %%
nta = requests.get('https://data.cityofnewyork.us/api/views/93vf-i5bz/rows.json?accessType=DOWNLOAD').json()

# %%
nta.keys()
# Out:
# dict_keys(['meta', 'data'])

# %%
rows = []
rows_num = len(nta['data'])
for row in range(rows_num):
    rows.append(nta['data'][row][8:])
nta_area = pd.DataFrame(rows, columns = ['geom', 'BoroCode', 'Borough', 'CountyFIPS', 'NTACode', 'Neighborhood',
       'Shape_Leng', 'Shape_Area'])

# %%
nta['data'][0]
# Out:
# ['row-fdbg-rsfm-b28b',
#  '00000000-0000-0000-D9DD-2BE071F8978C',
#  0,
#  1450733148,
#  None,
#  1450733148,
#  None,
#  '{ }',
#  'MULTIPOLYGON (((-73.94732672160586 40.62916656720947, -73.94687439946745 40.626773668128536, -73.94642266064325 40.62438556728645, -73.94542442897415 40.62449560959823, -73.94497031348955 40.62210451293764, -73.94451833370505 40.61971364709508, -73.94551663574792 40.61960561195174, -73.94651373193835 40.61949401914997, -73.94606699612437 40.61710373918019, -73.945763594919 40.61550406422126, -73.94573691912035 40.61536340675665, -73.94657366828146 40.614789131137535, -73.94742608780814 40.61422460055368, -73.94772682569703 40.61416971618289, -73.94834517370126 40.614136496631644, -73.94930527478502 40.61403073451604, -73.95026514882969 40.61392435179741, -73.94999598103782 40.612491461663254, -73.94996296695332 40.612315727849385, -73.94993049319113 40.6121446508932, -73.94978380450684 40.611371750477694, -73.95070512926125 40.61125045222408, -73.95163235049947 40.61112353986174, -73.95256553090692 40.610987184733965, -73.95258786948979 40.61111223958905, -73.95359888852914 40.610949865606415, -73.9547955271003 40.61082076565259, -73.95574066989153 40.61071482745622, -73.95670471406353 40.61061187782893, -73.9576680137944 40.61050371521898, -73.9580473192723 40.61046276244425, -73.95859278495774 40.61040303093508, -73.95952069567834 40.6103020528368, -73.96044361881546 40.61020150680258, -73.9613726831359 40.61009887471164, -73.96237947824771 40.60998637452585, -73.96285973961463 40.612549486467046, -73.96336094023268 40.615204428336206, -73.96356470625163 40.61623872246751, -73.96362245555169 40.61658973720423, -73.96375418658931 40.617302433542974, -73.96381145170669 40.61758940154461, -73.96388935578916 40.618000549884364, -73.96426798339401 40.6199838032854, -73.96471983385591 40.62237296070274, -73.96571874618468 40.62226402946434, -73.9666451571374 40.62216223742479, -73.96757137736043 40.62206027486026, -73.96864510622696 40.62194169581487, -73.96909724465469 40.62433282513802, -73.97019276977223 40.624203249974194, -73.97047171931142 40.62417003048167, -73.97080408232932 40.62593266659033, -73.97086150876686 40.62623718333577, -73.97092126268784 40.62656998550552, -73.97111421951189 40.62758588368451, -73.97120750524219 40.62808971219776, -73.97136622157032 40.62892916271589, -73.97109232328968 40.62896614062424, -73.97000109763489 40.62911347375601, -73.96892915890132 40.62923162562481, -73.96800084402996 40.629333058215195, -73.96707656865335 40.62943468164797, -73.96608191359873 40.6295427068263, -73.9650807282895 40.62965467559488, -73.96414862835252 40.62973896556128, -73.96322149343035 40.62984106103685, -73.96232599364598 40.62996871673761, -73.96197454283195 40.629995041080385, -73.96182099849084 40.630004877401824, -73.9616363994039 40.630022223018415, -73.96136921593195 40.630058388262455, -73.96046280639713 40.630155661219476, -73.96040734342061 40.63016253057628, -73.96025855010787 40.6294182625654, -73.96024902920543 40.629370621832436, -73.9602256005792 40.62925450129715, -73.96014773493869 40.62891518541706, -73.95995565121842 40.627778672540636, -73.9589941629722 40.627885594543145, -73.95805293146628 40.627971118632, -73.95684697280602 40.62811987905406, -73.95581207194958 40.62823349190701, -73.9548849915694 40.62833554833743, -73.95395983418416 40.62843938961409, -73.95303133100145 40.62854011509271, -73.95206901809611 40.62864578101477, -73.95110641920346 40.628750467094555, -73.95017656950539 40.62885277202811, -73.94925229833636 40.62895476532659, -73.94832386196282 40.6290566605328, -73.94732672160586 40.62916656720947)))',
#  '3',
#  'Brooklyn',
#  '047',
#  'BK43',
#  'Midwood',
#  '27996.5912736',
#  '35799637.8103']

# %%
nta_area.head()
# Out:
#                                                 geom BoroCode   Borough  \
# 0  MULTIPOLYGON (((-73.94732672160586 40.62916656...        3  Brooklyn
# 1  MULTIPOLYGON (((-73.94193078816201 40.70072523...        3  Brooklyn
# 2  MULTIPOLYGON (((-73.89138023380268 40.86170058...        2     Bronx
# 3  MULTIPOLYGON (((-73.9760493559142 40.631275905...        3  Brooklyn
# 4  MULTIPOLYGON (((-73.90855790522774 40.65209593...        3  Brooklyn
#
#   CountyFIPS NTACode          Neighborhood     Shape_Leng     Shape_Area
# 0        047    BK43               Midwood  27996.5912736  35799637.8103
# 1        047    BK75               Bedford  29992.9191744  32629833.1149
# 2        005    BX40         Fordham South  15878.2729212  6307283.62202
# 3        047    BK88          Borough Park   39247.227722  54005019.2286
# 4        047    BK96  Rugby-Remsen Village  30957.8533949  32706946.4035

# %%
dff = pd.read_csv('nynta.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-132-19bcd8c9f63d> in <module>
# ----> 1 dff = pd.read_csv('nynta.csv')
#
# C:\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# --> 702         return _read(filepath_or_buffer, kwds)
#     703
#     704     parser_f.__name__ = name
#
# C:\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     427
#     428     # Create the parser.
# --> 429     parser = TextFileReader(filepath_or_buffer, **kwds)
#     430
#     431     if chunksize or iterator:
#
# C:\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options['has_index_names'] = kwds['has_index_names']
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# C:\Anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1120     def _make_engine(self, engine='c'):
#    1121         if engine == 'c':
# -> 1122             self._engine = CParserWrapper(self.f, **self.options)
#    1123         else:
#    1124             if engine == 'python':
#
# C:\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1851         kwds['usecols'] = self.usecols
#    1852
# -> 1853         self._reader = parsers.TextReader(src, **kwds)
#    1854         self.unnamed_cols = self._reader.unnamed_cols
#    1855
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'nynta.csv' does not exist: b'nynta.csv'

# %%
len(dff), len(nta_area)
# Out:
# (195, 195)

# %%
dff.head()
# Out:
#                                             the_geom  BoroCode  BoroName  \
# 0  MULTIPOLYGON (((-73.94732672160586 40.62916656...         3  Brooklyn
# 1  MULTIPOLYGON (((-73.94193078816201 40.70072523...         3  Brooklyn
# 2  MULTIPOLYGON (((-73.89138023380268 40.86170058...         2     Bronx
# 3  MULTIPOLYGON (((-73.9760493559142 40.631275905...         3  Brooklyn
# 4  MULTIPOLYGON (((-73.90855790522774 40.65209593...         3  Brooklyn
#
#    CountyFIPS NTACode               NTAName      Shape_Leng       Shape_Area
# 0          47    BK43               Midwood  27,996.5912736  35,799,637.8103
# 1          47    BK75               Bedford  29,992.9191744  32,629,833.1149
# 2           5    BX40         Fordham South  15,878.2729212  6,307,283.62202
# 3          47    BK88          Borough Park   39,247.227722  54,005,019.2286
# 4          47    BK96  Rugby-Remsen Village  30,957.8533949  32,706,946.4035

# %%
dff[dff['CountyFIPS']== 25]
# Out:
# Empty DataFrame
# Columns: [the_geom, BoroCode, BoroName, CountyFIPS, NTACode, NTAName, Shape_Leng, Shape_Area]
# Index: []

# %% [markdown]
# # Crime Dataset

# %%
crime = requests.get('https://data.cityofnewyork.us/api/views/5uac-w243/rows.json?accessType=DOWNLOAD').json()

# %%
crime['data']
# Out:
# [['row-jqjg_evtp-tn4b',
#   '00000000-0000-0000-0620-6B6BF1A1C9F4',
#   0,
#   1579297663,
#   None,
#   1579297833,
#   None,
#   '{ }',
#   '314773184',
#   '48',
#   'BRONX',
#   '2019-12-31T00:00:00',
#   '18:00:00',
#   None,
#   None,
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '105',
#   'FELONY',
#   None,
#   'ROBBERY',
#   None,
#   'PATROL BORO BRONX',
#   '386.0',
#   'ROBBERY,PERSONAL ELECTRONIC DEVICE',
#   'STREET',
#   '2019-12-31T00:00:00',
#   None,
#   'UNKNOWN',
#   'UNKNOWN',
#   'U',
#   None,
#   '45-64',
#   'WHITE HISPANIC',
#   'F',
#   '1016990',
#   '244612',
#   '40.838026269000075',
#   '-73.88168118799997',
#   [None, '40.838026269000075', '-73.88168118799997', None, False],
#   '11269',
#   '35',
#   '5',
#   '43',
#   '31'],
#  ['row-tedt.nvuf~r8u3',
#   '00000000-0000-0000-9756-1909A41F0A3A',
#   0,
#   1579297663,
#   None,
#   1579297833,
#   None,
#   '{ }',
#   '289837961',
#   '25',
#   'MANHATTAN',
#   '2019-12-30T00:00:00',
#   '20:30:00',
#   '2019-12-31T00:00:00',
#   '10:00:00',
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '341',
#   'MISDEMEANOR',
#   'INSIDE',
#   'PETIT LARCENY',
#   None,
#   'PATROL BORO MAN NORTH',
#   '338.0',
#   'LARCENY,PETIT FROM BUILDING,UN',
#   'RESIDENCE - APT. HOUSE',
#   '2019-12-31T00:00:00',
#   None,
#   None,
#   None,
#   None,
#   None,
#   '25-44',
#   'WHITE HISPANIC',
#   'F',
#   '999296',
#   '230862',
#   '40.800334261000046',
#   '-73.94565697199994',
#   [None, '40.800334261000046', '-73.94565697199994', None, False],
#   '13093',
#   '7',
#   '4',
#   '36',
#   '16'],
#  ['row-mrrk~3rsx.hgxw',
#   '00000000-0000-0000-7D3A-9B2A31153503',
#   0,
#   1579297663,
#   None,
#   1579297833,
#   None,
#   '{ }',
#   '535744284',
#   '77',
#   'BROOKLYN',
#   '2019-12-24T00:00:00',
#   '16:55:00',
#   '2019-12-24T00:00:00',
#   '17:00:00',
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '106',
#   'FELONY',
#   None,
#   'FELONY ASSAULT',
#   None,
#   'PATROL BORO BKLYN NORTH',
#   '109.0',
#   'ASSAULT 2,1,UNCLASSIFIED',
#   'STREET',
#   '2019-12-31T00:00:00',
#   None,
#   'UNKNOWN',
#   'BLACK',
#   'M',
#   None,
#   '18-24',
#   'WHITE',
#   'M',
#   '1001068',
#   '183317',
#   '40.66983179600004',
#   '-73.93937555099996',
#   [None, '40.66983179600004', '-73.93937555099996', None, False],
#   '17615',
#   '16',
#   '2',
#   '48',
#   '49'],
#  ['row-6qms-2i4j_anvu',
#   '00000000-0000-0000-A7EB-D02D5706CA37',
#   0,
#   1579297663,
#   None,
#   1579297833,
#   None,
#   '{ }',
#   '895678119',
#   '52',
#   'BRONX',
#   '2019-12-30T00:00:00',
#   '19:32:00',
#   None,
#   None,
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '341',
#   'MISDEMEANOR',
#   'INSIDE',
#   'PETIT LARCENY',
#   None,
#   'PATROL BORO BRONX',
#   '333.0',
#   'LARCENY,PETIT FROM STORE-SHOPL',
#   'CHAIN STORE',
#   '2019-12-30T00:00:00',
#   None,
#   '25-44',
#   'WHITE',
#   'F',
#   None,
#   'UNKNOWN',
#   'UNKNOWN',
#   'D',
#   '1009690',
#   '257590',
#   '40.87367103500002',
#   '-73.90801364899994',
#   [None, '40.87367103500002', '-73.90801364899994', None, False],
#   '11272',
#   '48',
#   '4',
#   '39',
#   '33'],
#  ['row-w62t.szzi-d9de',
#   '00000000-0000-0000-57FE-CC85D5C25FBA',
#   0,
#   1579297663,
#   None,
#   1579297833,
#   None,
#   '{ }',
#   '299841674',
#   '18',
#   'MANHATTAN',
#   '2019-12-30T00:00:00',
#   '15:30:00',
#   '2019-12-30T00:00:00',
#   '16:50:00',
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '341',
#   'MISDEMEANOR',
#   None,
#   'PETIT LARCENY',
#   None,
#   'PATROL BORO MAN SOUTH',
#   '301.0',
#   'LARCENY,PETIT BY ACQUIRING LOS',
#   'STREET',
#   '2019-12-30T00:00:00',
#   None,
#   None,
#   None,
#   None,
#   None,
#   '25-44',
#   'WHITE HISPANIC',
#   'M',
#   '985766',
#   '216503',
#   '40.76093528000007',
#   '-73.99452906599998',
#   [None, '40.76093528000007', '-73.99452906599998', None, False],
#   '13094',
#   '12',
#   '4',
#   '10',
#   '10'],
#  ['row-x2ib.uk5p-fffg',
#   '00000000-0000-0000-9BC1-5D45E3FA36C4',
#   0,
#   1579297663,
#   None,
#   1579297833,
#   None,
#   '{ }',
#   '136697381',
#   '94',
#   'BROOKLYN',
#   '2019-12-28T00:00:00',
#   '13:00:00',
#   '2019-12-29T00:00:00',
#   '08:30:00',
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '341',
#   'MISDEMEANOR',
#   'INSIDE',
#   'PETIT LARCENY',
#   None,
#   'PATROL BORO BKLYN NORTH',
#   '349.0',
#   'LARCENY,PETIT OF LICENSE PLATE',
#   'STREET',
#   '2019-12-30T00:00:00',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'UNKNOWN',
#   'UNKNOWN',
#   'D',
#   '997964',
#   '205703',
#   '40.73128148300003',
#   '-73.95051933399996',
#   [None, '40.73128148300003', '-73.95051933399996', None, False],
#   '18182',
#   '36',
#   '2',
#   '38',
#   '57'],
#  ['row-aktm.3w9i.8pxn',
#   '00000000-0000-0000-3270-B4436FC7F902',
#   0,
#   1579297663,
#   None,
#   1579297833,
#   None,
#   '{ }',
#   '628084657',
#   '69',
#   'BROOKLYN',
#   '2019-12-22T00:00:00',
#   '16:30:00',
#   None,
#   None,
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '344',
#   'MISDEMEANOR',
#   'FRONT OF',
#   'ASSAULT 3 & RELATED OFFENSES',
#   None,
#   'PATROL BORO BKLYN SOUTH',
#   '101.0',
#   'ASSAULT 3',
#   'STREET',
#   '2019-12-30T00:00:00',
#   None,
#   '25-44',
#   'BLACK',
#   'M',
#   None,
#   '25-44',
#   'BLACK',
#   'M',
#   '1010537',
#   '168507',
#   '40.629158526000026',
#   '-73.90529923099997',
#   [None, '40.629158526000026', '-73.90529923099997', None, False],
#   '13827',
#   '5',
#   '2',
#   '8',
#   '42'],
#  ['row-bci9~pidk.j7nf',
#   '00000000-0000-0000-A834-9DE234445520',
#   0,
#   1579297663,
#   None,
#   1579297833,
#   None,
#   '{ }',
#   '487138011',
#   '43',
#   'BRONX',
#   '2019-12-29T00:00:00',
#   '17:20:00',
#   None,
#   None,
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '105',
#   'FELONY',
#   'FRONT OF',
#   'ROBBERY',
#   None,
#   'PATROL BORO BRONX',
#   '386.0',
#   'ROBBERY,PERSONAL ELECTRONIC DEVICE',
#   'STREET',
#   '2019-12-29T00:00:00',
#   None,
#   'UNKNOWN',
#   'WHITE HISPANIC',
#   'M',
#   None,
#   '25-44',
#   'BLACK',
#   'M',
#   '1018876',
#   '241924',
#   '40.83064129700006',
#   '-73.87487918899996',
#   [None, '40.83064129700006', '-73.87487918899996', None, False],
#   '11610',
#   '58',
#   '5',
#   '31',
#   '26'],
#  ['row-z944~dr3p-i9a3',
#   '00000000-0000-0000-F429-C54934D0A5A7',
#   0,
#   1579297663,
#   None,
#   1579297833,
#   None,
#   '{ }',
#   '227601821',
#   '18',
#   'MANHATTAN',
#   '2019-12-29T00:00:00',
#   '12:30:00',
#   '2019-12-29T00:00:00',
#   '13:30:00',
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '233',
#   'MISDEMEANOR',
#   None,
#   'SEX CRIMES',
#   None,
#   'PATROL BORO MAN SOUTH',
#   '175.0',
#   'SEXUAL ABUSE 3,2',
#   'STREET',
#   '2019-12-29T00:00:00',
#   None,
#   'UNKNOWN',
#   'WHITE',
#   'M',
#   None,
#   '25-44',
#   'WHITE',
#   'F',
#   '988353',
#   '217918',
#   '40.764818269000045',
#   '-73.98518977299993',
#   [None, '40.764818269000045', '-73.98518977299993', None, False],
#   '12081',
#   '12',
#   '4',
#   '10',
#   '10'],
#  ['row-r4gf.cgaa-yvqq',
#   '00000000-0000-0000-6F48-F82A9E1CAB18',
#   0,
#   1579297663,
#   None,
#   1579297833,
#   None,
#   '{ }',
#   '536304115',
#   '13',
#   'MANHATTAN',
#   '2019-12-28T00:00:00',
#   '15:05:00',
#   '2019-12-28T00:00:00',
#   '15:10:00',
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '578',
#   'VIOLATION',
#   'INSIDE',
#   'HARRASSMENT 2',
#   None,
#   'PATROL BORO MAN SOUTH',
#   '637.0',
#   'HARASSMENT,SUBD 1,CIVILIAN',
#   'RESIDENCE - APT. HOUSE',
#   '2019-12-28T00:00:00',
#   None,
#   '65+',
#   'WHITE',
#   'F',
#   None,
#   '18-24',
#   'ASIAN / PACIFIC ISLANDER',
#   'F',
#   '985850',
#   '210155',
#   '40.74351160900005',
#   '-73.99422735499998',
#   [None, '40.74351160900005', '-73.99422735499998', None, False],
#   '12074',
#   '12',
#   '4',
#   '10',
#   '7'],
#  ['row-hh2c~993m.5nex',
#   '00000000-0000-0000-BDE4-7AD686B542E8',
#   0,
#   1579297663,
#   None,
#   1579297833,
#   None,
#   '{ }',
#   '355744896',
#   '46',
#   'BRONX',
#   '2019-12-28T00:00:00',
#   '14:10:00',
#   '2019-12-28T00:00:00',
#   '14:23:00',
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '578',
#   'VIOLATION',
#   'INSIDE',
#   'HARRASSMENT 2',
#   None,
#   'PATROL BORO BRONX',
#   '638.0',
#   'HARASSMENT,SUBD 3,4,5',
#   'RESIDENCE - APT. HOUSE',
#   '2019-12-28T00:00:00',
#   None,
#   'UNKNOWN',
#   'BLACK',
#   'M',
#   None,
#   '25-44',
#   'BLACK HISPANIC',
#   'F',
#   '1011301',
#   '252369',
#   '40.85933619200006',
#   '-73.90220955699994',
#   [None, '40.85933619200006', '-73.90220955699994', None, False],
#   '11606',
#   '6',
#   '5',
#   '29',
#   '29'],
#  ['row-s68j.tips-zc75',
#   '00000000-0000-0000-4E1F-1078DED8C880',
#   0,
#   1579297663,
#   None,
#   1579297833,
#   None,
#   '{ }',
#   '754294853',
#   '19',
#   'MANHATTAN',
#   '2019-12-28T00:00:00',
#   '11:30:00',
#   '2019-12-28T00:00:00',
#   '17:00:00',
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '109',
#   'FELONY',
#   'INSIDE',
#   'GRAND LARCENY',
#   None,
#   'PATROL BORO MAN NORTH',
#   '407.0',
#   'LARCENY,GRAND BY DISHONEST EMP',
#   'CHAIN STORE',
#   '2019-12-28T00:00:00',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'UNKNOWN',
#   'UNKNOWN',
#   'D',
#   '993570',
#   '216847',
#   '40.76187469000007',
#   '-73.96635808399996',
#   [None, '40.76187469000007', '-73.96635808399996', None, False],
#   '12419',
#   '23',
#   '4',
#   '51',
#   '11'],
#  ['row-wxad~g6mi_zqb5',
#   '00000000-0000-0000-96F2-79A15FEBF685',
#   0,
#   1579297663,
#   None,
#   1579297833,
#   None,
#   '{ }',
#   '600940250',
#   '69',
#   'BROOKLYN',
#   '2019-12-27T00:00:00',
#   '12:00:00',
#   None,
#   None,
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '112',
#   'FELONY',
#   'INSIDE',
#   'THEFT-FRAUD',
#   None,
#   'PATROL BORO BKLYN SOUTH',
#   '739.0',
#   'FRAUD,UNCLASSIFIED-FELONY',
#   'RESIDENCE - APT. HOUSE',
#   '2019-12-27T00:00:00',
#   None,
#   'UNKNOWN',
#   'UNKNOWN',
#   'U',
#   None,
#   '65+',
#   'BLACK',
#   'F',
#   '1007166',
#   '171344',
#   '40.636954848000066',
#   '-73.91743403899994',
#   [None, '40.636954848000066', '-73.91743403899994', None, False],
#   '13827',
#   '5',
#   '2',
#   '8',
#   '42'],
#  ['row-b2hj.rnrb.fgpw',
#   '00000000-0000-0000-4C89-91B162A96990',
#   0,
#   1579297663,
#   None,
#   1579297833,
#   None,
#   '{ }',
#   '429316515',
#   '114',
#   'QUEENS',
#   '2019-12-27T00:00:00',
#   '04:20:00',
#   '2019-12-27T00:00:00',
#   '04:21:00',
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '344',
#   'MISDEMEANOR',
#   'INSIDE',
#   'ASSAULT 3 & RELATED OFFENSES',
#   None,
#   'PATROL BORO QUEENS NORTH',
#   '101.0',
#   'ASSAULT 3',
#   'HOSPITAL',
#   '2019-12-27T00:00:00',
#   None,
#   'UNKNOWN',
#   'UNKNOWN',
#   'U',
#   None,
#   'UNKNOWN',
#   'UNKNOWN',
#   'E',
#   '1005115',
#   '219246',
#   '40.76843961600008',
#   '-73.92467547699994',
#   [None, '40.76843961600008', '-73.92467547699994', None, False],
#   '16859',
#   '39',
#   '3',
#   '4',
#   '72'],
#  ['row-hdtd_rfv3~vnub',
#   '00000000-0000-0000-9651-0D60272D839A',
#   0,
#   1579297663,
#   None,
#   1579297833,
#   None,
#   '{ }',
#   '518612337',
#   '44',
#   'BRONX',
#   '2019-12-26T00:00:00',
#   '13:59:00',
#   None,
#   None,
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '341',
#   'MISDEMEANOR',
#   'INSIDE',
#   'PETIT LARCENY',
#   None,
#   'PATROL BORO BRONX',
#   '339.0',
#   'LARCENY,PETIT FROM OPEN AREAS,',
#   'STREET',
#   '2019-12-26T00:00:00',
#   None,
#   None,
#   None,
#   None,
#   None,
#   '25-44',
#   'WHITE HISPANIC',
#   'F',
#   '1006839',
#   '245065',
#   '40.83930142000003',
#   '-73.91836470099996',
#   [None, '40.83930142000003', '-73.91836470099996', None, False],
#   '10930',
#   '50',
#   '5',
#   '42',
#   '27'],
#  ['row-5jnr-uztm~8vb5',
#   '00000000-0000-0000-77A2-9B4ABD337D23',
#   0,
#   1579297663,
#   None,
#   1579297833,
#   None,
#   '{ }',
#   '365001231',
#   '26',
#   'MANHATTAN',
#   '2019-12-25T00:00:00',
#   '17:10:00',
#   '2019-12-25T00:00:00',
#   '17:15:00',
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '341',
#   'MISDEMEANOR',
#   None,
#   'PETIT LARCENY',
#   None,
#   'PATROL BORO MAN NORTH',
#   '321.0',
#   'LARCENY,PETIT FROM AUTO',
#   'OTHER',
#   '2019-12-25T00:00:00',
#   None,
#   None,
#   None,
#   None,
#   None,
#   '25-44',
#   'BLACK',
#   'M',
#   '999174',
#   '238490',
#   '40.82127120900003',
#   '-73.94608066499995',
#   [None, '40.82127120900003', '-73.94608066499995', None, False],
#   '12428',
#   '37',
#   '4',
#   '23',
#   '19'],
#  ['row-8pt8_fbwc~4gz5',
#   '00000000-0000-0000-DE2B-659FDC591CA7',
#   0,
#   1579297663,
#   None,
#   1579297833,
#   None,
#   '{ }',
#   '271699374',
#   '41',
#   'BRONX',
#   '2019-12-25T00:00:00',
#   '11:20:00',
#   None,
#   None,
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '578',
#   'VIOLATION',
#   'INSIDE',
#   'HARRASSMENT 2',
#   None,
#   'PATROL BORO BRONX',
#   '638.0',
#   'HARASSMENT,SUBD 3,4,5',
#   'STREET',
#   '2019-12-25T00:00:00',
#   None,
#   '65+',
#   'WHITE HISPANIC',
#   'M',
#   None,
#   '45-64',
#   'WHITE HISPANIC',
#   'F',
#   '1015387',
#   '237462',
#   '40.818407371000035',
#   '-73.88750750299994',
#   [None, '40.818407371000035', '-73.88750750299994', None, False],
#   '12343',
#   '8',
#   '5',
#   '43',
#   '24'],
#  ['row-2dfx.dxg9_wgvs',
#   '00000000-0000-0000-F531-FC3BC5D4F6C4',
#   0,
#   1579297663,
#   None,
#   1579297833,
#   None,
#   '{ }',
#   '186563977',
#   '52',
#   'BRONX',
#   '2019-12-24T00:00:00',
#   '23:00:00',
#   None,
#   None,
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '341',
#   'MISDEMEANOR',
#   None,
#   'PETIT LARCENY',
#   None,
#   'PATROL BORO BRONX',
#   '321.0',
#   'LARCENY,PETIT FROM AUTO',
#   'STREET',
#   '2019-12-25T00:00:00',
#   None,
#   'UNKNOWN',
#   'UNKNOWN',
#   'U',
#   None,
#   '18-24',
#   'WHITE HISPANIC',
#   'F',
#   '1014081',
#   '259196',
#   '40.87806525900004',
#   '-73.89212921499995',
#   [None, '40.87806525900004', '-73.89212921499995', None, False],
#   '11272',
#   '48',
#   '5',
#   '40',
#   '33'],
#  ['row-vngx.tiy9.btn3',
#   '00000000-0000-0000-B8A9-E6C376BC22A0',
#   0,
#   1579297663,
#   None,
#   1579297833,
#   None,
#   '{ }',
#   '815149872',
#   '44',
#   'BRONX',
#   '2019-12-20T00:00:00',
#   '17:00:00',
#   None,
#   None,
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '109',
#   'FELONY',
#   None,
#   'GRAND LARCENY',
#   None,
#   'PATROL BORO BRONX',
#   '421.0',
#   'LARCENY,GRAND FROM VEHICLE/MOTORCYCLE',
#   'STREET',
#   '2019-12-25T00:00:00',
#   None,
#   'UNKNOWN',
#   'UNKNOWN',
#   'U',
#   None,
#   '45-64',
#   'BLACK',
#   'F',
#   '1005731',
#   '243904',
#   '40.83611757700004',
#   '-73.92237273499995',
#   [None, '40.83611757700004', '-73.92237273499995', None, False],
#   '10930',
#   '50',
#   '5',
#   '42',
#   '27'],
#  ['row-fth3-y9bw.8tqv',
#   '00000000-0000-0000-D69E-2748D0E27123',
#   0,
#   1579297663,
#   None,
#   1579297833,
#   None,
#   '{ }',
#   '708944208',
#   '20',
#   'MANHATTAN',
#   '2019-12-24T00:00:00',
#   '14:45:00',
#   None,
#   None,
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '578',
#   'VIOLATION',
#   None,
#   'HARRASSMENT 2',
#   None,
#   'PATROL BORO MAN NORTH',
#   '638.0',
#   'HARASSMENT,SUBD 3,4,5',
#   'STREET',
#   '2019-12-24T00:00:00',
#   None,
#   None,
#   None,
#   None,
#   None,
#   '45-64',
#   'WHITE',
#   'M',
#   '989197',
#   '222103',
#   '40.77630457400005',
#   '-73.98213988499998',
#   [None, '40.77630457400005', '-73.98213988499998', None, False],
#   '12420',
#   '20',
#   '4',
#   '19',
#   '12'],
#  ['row-cmjc~p768-29n7',
#   '00000000-0000-0000-9906-AADBEBB8C3A2',
#   0,
#   1579297663,
#   None,
#   1579297833,
#   None,
#   '{ }',
#   '393137001',
#   '43',
#   'BRONX',
#   '2019-12-24T00:00:00',
#   '14:06:00',
#   None,
#   None,
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '106',
#   'FELONY',
#   'INSIDE',
#   'FELONY ASSAULT',
#   None,
#   'PATROL BORO BRONX',
#   '109.0',
#   'ASSAULT 2,1,UNCLASSIFIED',
#   'RESIDENCE - APT. HOUSE',
#   '2019-12-24T00:00:00',
#   None,
#   None,
#   None,
#   None,
#   None,
#   '<18',
#   'BLACK HISPANIC',
#   'M',
#   '1021666',
#   '238469',
#   '40.821146937000044',
#   '-73.86481670799998',
#   [None, '40.821146937000044', '-73.86481670799998', None, False],
#   '11611',
#   '58',
#   '5',
#   '31',
#   '26'],
#  ['row-pkgg-ppzv~giv5',
#   '00000000-0000-0000-F9F9-B566D5CF7967',
#   0,
#   1579297663,
#   None,
#   1579297833,
#   None,
#   '{ }',
#   '491009906',
#   '68',
#   'BROOKLYN',
#   '2019-12-24T00:00:00',
#   '13:15:00',
#   None,
#   None,
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '107',
#   'FELONY',
#   'OPPOSITE OF',
#   'BURGLARY',
#   None,
#   'PATROL BORO BKLYN SOUTH',
#   '231.0',
#   'BURGLARY,TRUCK DAY',
#   'STREET',
#   '2019-12-24T00:00:00',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'UNKNOWN',
#   'UNKNOWN',
#   'D',
#   '981251',
#   '169739',
#   '40.63257859700008',
#   '-74.01080626599996',
#   [None, '40.63257859700008', '-74.01080626599996', None, False],
#   '18180',
#   '10',
#   '2',
#   '7',
#   '41'],
#  ['row-vq6c~xhq2.96wr',
#   '00000000-0000-0000-A367-2738D171BA20',
#   0,
#   1579297663,
#   None,
#   1579297833,
#   None,
#   '{ }',
#   '163547994',
#   '100',
#   'QUEENS',
#   '2019-12-24T00:00:00',
#   '03:53:00',
#   None,
#   None,
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '347',
#   'MISDEMEANOR',
#   None,
#   'INTOXICATED & IMPAIRED DRIVING',
#   None,
#   'PATROL BORO QUEENS SOUTH',
#   '905.0',
#   'INTOXICATED DRIVING,ALCOHOL',
#   'STREET',
#   '2019-12-24T00:00:00',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'UNKNOWN',
#   'UNKNOWN',
#   'E',
#   '1023135',
#   '147347',
#   '40.571032339000055',
#   '-73.86003522499993',
#   [None, '40.571032339000055', '-73.86003522499993', None, False],
#   '20532',
#   '51',
#   '3',
#   '41',
#   '58'],
#  ['row-rugj_qgub.54ve',
#   '00000000-0000-0000-E7FC-7595FC005F39',
#   0,
#   1579297663,
#   None,
#   1579297833,
#   None,
#   '{ }',
#   '282077551',
#   '44',
#   'BRONX',
#   '2019-12-23T00:00:00',
#   '17:05:00',
#   None,
#   None,
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '348',
#   'MISDEMEANOR',
#   None,
#   'VEHICLE AND TRAFFIC LAWS',
#   None,
#   'PATROL BORO BRONX',
#   '916.0',
#   'LEAVING SCENE-ACCIDENT-PERSONA',
#   'STREET',
#   '2019-12-23T00:00:00',
#   None,
#   None,
#   None,
#   None,
#   None,
#   '25-44',
#   'WHITE HISPANIC',
#   'F',
#   '1004152',
#   '238742',
#   '40.82195306500005',
#   '-73.92809428499999',
#   [None, '40.82195306500005', '-73.92809428499999', None, False],
#   '10929',
#   '50',
#   '5',
#   '35',
#   '27'],
#  ['row-fiee_zhca~tf23',
#   '00000000-0000-0000-75D3-2A324FFED129',
#   0,
#   1579297663,
#   None,
#   1579297833,
#   None,
#   '{ }',
#   '260307851',
#   '5',
#   'MANHATTAN',
#   '2019-12-23T00:00:00',
#   '14:41:00',
#   None,
#   None,
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '105',
#   'FELONY',
#   None,
#   'ROBBERY',
#   None,
#   'PATROL BORO MAN SOUTH',
#   '383.0',
#   'ROBBERY,DELIVERY PERSON',
#   'STREET',
#   '2019-12-23T00:00:00',
#   None,
#   '25-44',
#   'WHITE HISPANIC',
#   'M',
#   None,
#   '45-64',
#   'ASIAN / PACIFIC ISLANDER',
#   'M',
#   '984998',
#   '199212',
#   '40.713475851000055',
#   '-73.99730327399999',
#   [None, '40.713475851000055', '-73.99730327399999', None, False],
#   '11723',
#   '70',
#   '4',
#   '32',
#   '2'],
#  ['row-iwe9-iabg-h4tp',
#   '00000000-0000-0000-9FD5-15147C6D0238',
#   0,
#   1579297663,
#   None,
#   1579297833,
#   None,
#   '{ }',
#   '220063575',
#   '68',
#   'BROOKLYN',
#   '2019-12-22T00:00:00',
#   '22:10:00',
#   None,
#   None,
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '578',
#   'VIOLATION',
#   'INSIDE',
#   'HARRASSMENT 2',
#   None,
#   'PATROL BORO BKLYN SOUTH',
#   '638.0',
#   'HARASSMENT,SUBD 3,4,5',
#   'RESIDENCE - APT. HOUSE',
#   '2019-12-22T00:00:00',
#   None,
#   '45-64',
#   'BLACK',
#   'M',
#   None,
#   'UNKNOWN',
#   'UNKNOWN',
#   'M',
#   '975432',
#   '167102',
#   '40.625336705000045',
#   '-74.03176756699997',
#   [None, '40.625336705000045', '-74.03176756699997', None, False],
#   '17216',
#   '10',
#   '2',
#   '44',
#   '41'],
#  ['row-qysq-fm8w~higb',
#   '00000000-0000-0000-6A0B-B3597DE4A6F5',
#   0,
#   1579297663,
#   None,
#   1579297833,
#   None,
#   '{ }',
#   '820581356',
#   '40',
#   'BRONX',
#   '2019-12-22T00:00:00',
#   '16:50:00',
#   '2019-12-22T00:00:00',
#   '17:00:00',
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '113',
#   'FELONY',
#   None,
#   'FORGERY',
#   None,
#   'PATROL BORO BRONX',
#   '729.0',
#   'FORGERY,ETC.,UNCLASSIFIED-FELO',
#   'STREET',
#   '2019-12-22T00:00:00',
#   None,
#   '18-24',
#   'BLACK',
#   'M',
#   None,
#   'UNKNOWN',
#   'UNKNOWN',
#   'E',
#   '1011097',
#   '236699',
#   '40.81632723000007',
#   '-73.90300975599996',
#   [None, '40.81632723000007', '-73.90300975599996', None, False],
#   '10933',
#   '49',
#   '5',
#   '43',
#   '23'],
#  ['row-9442.7sp6.ri3p',
#   '00000000-0000-0000-2FFB-D1410588C28D',
#   0,
#   1579297663,
#   None,
#   1579297833,
#   None,
#   '{ }',
#   '778580015',
#   '111',
#   'QUEENS',
#   '2019-12-22T00:00:00',
#   '10:00:00',
#   '2019-12-22T00:00:00',
#   '10:03:00',
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '578',
#   'VIOLATION',
#   'REAR OF',
#   'HARRASSMENT 2',
#   None,
#   'PATROL BORO QUEENS NORTH',
#   '638.0',
#   'HARASSMENT,SUBD 3,4,5',
#   'RESIDENCE - APT. HOUSE',
#   '2019-12-22T00:00:00',
#   None,
#   '65+',
#   'WHITE',
#   'M',
#   None,
#   '65+',
#   'WHITE',
#   'M',
#   '1049819',
#   '208499',
#   '40.73872339300004',
#   '-73.76339222899996',
#   [None, '40.73872339300004', '-73.76339222899996', None, False],
#   '14506',
#   '25',
#   '3',
#   '16',
#   '65'],
#  ['row-xmwe.i7qn_mcy8',
#   '00000000-0000-0000-0CF0-6CBF96270501',
#   0,
#   1579297663,
#   None,
#   1579297833,
#   None,
#   '{ }',
#   '175176016',
#   '47',
#   'BRONX',
#   '2019-12-22T00:00:00',
#   '00:15:00',
#   None,
#   None,
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '105',
#   'FELONY',
#   'FRONT OF',
#   'ROBBERY',
#   None,
#   'PATROL BORO BRONX',
#   '386.0',
#   'ROBBERY,PERSONAL ELECTRONIC DEVICE',
#   'STREET',
#   '2019-12-22T00:00:00',
#   None,
#   '18-24',
#   'BLACK',
#   'U',
#   None,
#   '45-64',
#   'BLACK',
#   'M',
#   '1023120',
#   '262337',
#   '40.88665113600007',
#   '-73.85942499899994',
#   [None, '40.88665113600007', '-73.85942499899994', None, False],
#   '11275',
#   '29',
#   '5',
#   '2',
#   '30'],
#  ['row-uae5_9kw2~2ung',
#   '00000000-0000-0000-2769-11755F9070C2',
#   0,
#   1579297663,
#   None,
#   1579297833,
#   None,
#   '{ }',
#   '439187239',
#   '44',
#   'BRONX',
#   '2019-12-22T00:00:00',
#   '00:02:00',
#   None,
#   None,
#   'ATTEMPTED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '105',
#   'FELONY',
#   None,
#   'ROBBERY',
#   None,
#   'PATROL BORO BRONX',
#   '366.0',
#   'ROBBERY,BICYCLE',
#   'STREET',
#   '2019-12-22T00:00:00',
#   None,
#   'UNKNOWN',
#   'BLACK HISPANIC',
#   'M',
#   None,
#   '45-64',
#   'BLACK',
#   'M',
#   '1006834',
#   '245208',
#   '40.839693926000045',
#   '-73.91838228899996',
#   [None, '40.839693926000045', '-73.91838228899996', None, False],
#   '10930',
#   '50',
#   '5',
#   '42',
#   '27'],
#  ['row-eriv~ufxp~a54h',
#   '00000000-0000-0000-C514-434FB1E4A348',
#   0,
#   1579297663,
#   None,
#   1579297833,
#   None,
#   '{ }',
#   '755196195',
#   '40',
#   'BRONX',
#   '2019-12-21T00:00:00',
#   '20:00:00',
#   '2019-12-22T00:00:00',
#   '14:10:00',
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '341',
#   'MISDEMEANOR',
#   None,
#   'PETIT LARCENY',
#   None,
#   'PATROL BORO BRONX',
#   '321.0',
#   'LARCENY,PETIT FROM AUTO',
#   'STREET',
#   '2019-12-22T00:00:00',
#   None,
#   None,
#   None,
#   None,
#   None,
#   '25-44',
#   'WHITE HISPANIC',
#   'M',
#   '1007542',
#   '232103',
#   '40.80372257700003',
#   '-73.91586904699994',
#   [None, '40.80372257700003', '-73.91586904699994', None, False],
#   '10932',
#   '49',
#   '5',
#   '35',
#   '23'],
#  ['row-sffp.pmck-c8h5',
#   '00000000-0000-0000-CC10-4EE6BDE68160',
#   0,
#   1579297663,
#   None,
#   1579297833,
#   None,
#   '{ }',
#   '303436763',
#   '44',
#   'BRONX',
#   '2019-12-21T00:00:00',
#   '00:50:00',
#   None,
#   None,
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '105',
#   'FELONY',
#   'INSIDE',
#   'ROBBERY',
#   None,
#   'PATROL BORO BRONX',
#   '366.0',
#   'ROBBERY,BICYCLE',
#   'GROCERY/BODEGA',
#   '2019-12-21T00:00:00',
#   None,
#   '18-24',
#   'UNKNOWN',
#   'M',
#   None,
#   '25-44',
#   'WHITE HISPANIC',
#   'M',
#   '1005507',
#   '241210',
#   '40.82872386500002',
#   '-73.92319076799998',
#   [None, '40.82872386500002', '-73.92319076799998', None, False],
#   '10930',
#   '50',
#   '5',
#   '35',
#   '27'],
#  ['row-h6a3.7wvd-imdw',
#   '00000000-0000-0000-6CA3-3D1074256C23',
#   0,
#   1579297663,
#   None,
#   1579297833,
#   None,
#   '{ }',
#   '644402336',
#   '75',
#   'BROOKLYN',
#   '2019-12-20T00:00:00',
#   '19:53:00',
#   None,
#   None,
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '233',
#   'MISDEMEANOR',
#   'INSIDE',
#   'SEX CRIMES',
#   None,
#   'PATROL BORO BKLYN NORTH',
#   '681.0',
#   'CHILD, ENDANGERING WELFARE',
#   'GROCERY/BODEGA',
#   '2019-12-21T00:00:00',
#   None,
#   None,
#   None,
#   None,
#   None,
#   '<18',
#   'WHITE',
#   'M',
#   '1017141',
#   '183798',
#   '40.67110691100004',
#   '-73.88143295699997',
#   [None, '40.67110691100004', '-73.88143295699997', None, False],
#   '17215',
#   '45',
#   '2',
#   '25',
#   '47'],
#  ['row-pwg2.wpi9_refy',
#   '00000000-0000-0000-9FC7-24E0E4413DC2',
#   0,
#   1579297663,
#   None,
#   1579297841,
#   None,
#   '{ }',
#   '813677874',
#   '73',
#   'BROOKLYN',
#   '2019-12-20T00:00:00',
#   '23:35:00',
#   None,
#   None,
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '236',
#   'MISDEMEANOR',
#   None,
#   'DANGEROUS WEAPONS',
#   None,
#   'PATROL BORO BKLYN NORTH',
#   '782.0',
#   'WEAPONS, POSSESSION, ETC',
#   'STREET',
#   '2019-12-20T00:00:00',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'UNKNOWN',
#   'UNKNOWN',
#   'E',
#   '1009333',
#   '178895',
#   '40.657674832000055',
#   '-73.90959816699996',
#   [None, '40.657674832000055', '-73.90959816699996', None, False],
#   '17614',
#   '55',
#   '2',
#   '25',
#   '46'],
#  ['row-vvvd_ekx2.aapr',
#   '00000000-0000-0000-2CC0-FE202EC9E7B3',
#   0,
#   1579297663,
#   None,
#   1579297841,
#   None,
#   '{ }',
#   '494964008',
#   '48',
#   'BRONX',
#   '2019-12-20T00:00:00',
#   '15:10:00',
#   '2019-12-20T00:00:00',
#   '15:15:00',
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '105',
#   'FELONY',
#   None,
#   'ROBBERY',
#   None,
#   'PATROL BORO BRONX',
#   '386.0',
#   'ROBBERY,PERSONAL ELECTRONIC DEVICE',
#   'STREET',
#   '2019-12-20T00:00:00',
#   None,
#   'UNKNOWN',
#   'BLACK',
#   'U',
#   None,
#   '<18',
#   'WHITE HISPANIC',
#   'M',
#   '1015900',
#   '247717',
#   '40.84655255400003',
#   '-73.88560571999993',
#   [None, '40.84655255400003', '-73.88560571999993', None, False],
#   '11269',
#   '35',
#   '5',
#   '22',
#   '31'],
#  ['row-57te.atpd-bhew',
#   '00000000-0000-0000-4ABC-73E879DB471E',
#   0,
#   1579297663,
#   None,
#   1579297841,
#   None,
#   '{ }',
#   '134567076',
#   '44',
#   'BRONX',
#   '2019-12-20T00:00:00',
#   '12:15:00',
#   None,
#   None,
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '578',
#   'VIOLATION',
#   'INSIDE',
#   'HARRASSMENT 2',
#   None,
#   'PATROL BORO BRONX',
#   '638.0',
#   'HARASSMENT,SUBD 3,4,5',
#   'RESIDENCE - APT. HOUSE',
#   '2019-12-20T00:00:00',
#   None,
#   '25-44',
#   'BLACK',
#   'F',
#   None,
#   '25-44',
#   'BLACK',
#   'F',
#   '1005346',
#   '246531',
#   '40.84332885400005',
#   '-73.92375579599997',
#   [None, '40.84332885400005', '-73.92375579599997', None, False],
#   '10930',
#   '50',
#   '5',
#   '42',
#   '27'],
#  ['row-xft7~9rrr-axpq',
#   '00000000-0000-0000-CCAB-7FE0C889E110',
#   0,
#   1579297663,
#   None,
#   1579297841,
#   None,
#   '{ }',
#   '422809798',
#   '48',
#   'BRONX',
#   '2019-12-20T00:00:00',
#   '09:40:00',
#   '2019-12-20T00:00:00',
#   '10:20:00',
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '578',
#   'VIOLATION',
#   None,
#   'HARRASSMENT 2',
#   None,
#   'PATROL BORO BRONX',
#   '637.0',
#   'HARASSMENT,SUBD 1,CIVILIAN',
#   'STREET',
#   '2019-12-20T00:00:00',
#   None,
#   'UNKNOWN',
#   'UNKNOWN',
#   'U',
#   None,
#   '18-24',
#   'UNKNOWN',
#   'M',
#   '1012975',
#   '247755',
#   '40.846666852000055',
#   '-73.89617766499998',
#   [None, '40.846666852000055', '-73.89617766499998', None, False],
#   None,
#   '35',
#   '5',
#   '22',
#   '31'],
#  ['row-errq~qakx_g499',
#   '00000000-0000-0000-B3B9-A6A0590E801E',
#   0,
#   1579297663,
#   None,
#   1579297841,
#   None,
#   '{ }',
#   '123264418',
#   '73',
#   'BROOKLYN',
#   '2019-12-20T00:00:00',
#   '02:00:00',
#   '2019-12-20T00:00:00',
#   '08:00:00',
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '341',
#   'MISDEMEANOR',
#   'FRONT OF',
#   'PETIT LARCENY',
#   None,
#   'PATROL BORO BKLYN NORTH',
#   '321.0',
#   'LARCENY,PETIT FROM AUTO',
#   'STREET',
#   '2019-12-20T00:00:00',
#   None,
#   None,
#   None,
#   None,
#   None,
#   '45-64',
#   'WHITE',
#   'M',
#   '1010306',
#   '185838',
#   '40.67672900500003',
#   '-73.90606448399996',
#   [None, '40.67672900500003', '-73.90606448399996', None, False],
#   '13516',
#   '55',
#   '2',
#   '37',
#   '46'],
#  ['row-zrhn.fw9x.p9re',
#   '00000000-0000-0000-6E8E-54B9F2F6DCCE',
#   0,
#   1579297663,
#   None,
#   1579297841,
#   None,
#   '{ }',
#   '665301633',
#   '42',
#   'BRONX',
#   '2019-12-19T00:00:00',
#   '23:35:00',
#   '2019-12-19T00:00:00',
#   '23:38:00',
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '118',
#   'FELONY',
#   'FRONT OF',
#   'DANGEROUS WEAPONS',
#   None,
#   'PATROL BORO BRONX',
#   '793.0',
#   'WEAPONS POSSESSION 3',
#   'STREET',
#   '2019-12-20T00:00:00',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'UNKNOWN',
#   'UNKNOWN',
#   'E',
#   '1015430',
#   '243958',
#   '40.83623687500005',
#   '-73.88732196199999',
#   [None, '40.83623687500005', '-73.88732196199999', None, False],
#   '11269',
#   '34',
#   '5',
#   '43',
#   '25'],
#  ['row-4bxy-zrhh-7h8k',
#   '00000000-0000-0000-4956-902088EAF2BD',
#   0,
#   1579297663,
#   None,
#   1579297841,
#   None,
#   '{ }',
#   '183524599',
#   '47',
#   'BRONX',
#   '2019-12-19T00:00:00',
#   '19:16:00',
#   None,
#   None,
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '578',
#   'VIOLATION',
#   'INSIDE',
#   'HARRASSMENT 2',
#   None,
#   'PATROL BORO BRONX',
#   '638.0',
#   'HARASSMENT,SUBD 3,4,5',
#   'RESIDENCE-HOUSE',
#   '2019-12-19T00:00:00',
#   None,
#   '18-24',
#   'BLACK',
#   'F',
#   None,
#   '25-44',
#   'BLACK',
#   'M',
#   '1025620',
#   '260392',
#   '40.881301361000055',
#   '-73.85039557999994',
#   [None, '40.881301361000055', '-73.85039557999994', None, False],
#   '11607',
#   '29',
#   '5',
#   '2',
#   '30'],
#  ['row-2jnt-y7m5~cs74',
#   '00000000-0000-0000-AD5D-278D0429F06A',
#   0,
#   1579297663,
#   None,
#   1579297841,
#   None,
#   '{ }',
#   '473459248',
#   '77',
#   'BROOKLYN',
#   '2019-12-19T00:00:00',
#   '15:50:00',
#   '2019-12-19T00:00:00',
#   '16:00:00',
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '344',
#   'MISDEMEANOR',
#   None,
#   'ASSAULT 3 & RELATED OFFENSES',
#   None,
#   'PATROL BORO BKLYN NORTH',
#   '101.0',
#   'ASSAULT 3',
#   'STREET',
#   '2019-12-19T00:00:00',
#   None,
#   'UNKNOWN',
#   'UNKNOWN',
#   'M',
#   None,
#   '25-44',
#   'BLACK',
#   'M',
#   '1003404',
#   '183595',
#   '40.67059009900004',
#   '-73.93095390099995',
#   [None, '40.67059009900004', '-73.93095390099995', None, False],
#   '17615',
#   '16',
#   '2',
#   '49',
#   '49'],
#  ['row-unkf.fmgy.2nzf',
#   '00000000-0000-0000-58F5-ECA8E36F9AEA',
#   0,
#   1579297663,
#   None,
#   1579297841,
#   None,
#   '{ }',
#   '835266811',
#   '44',
#   'BRONX',
#   '2019-12-19T00:00:00',
#   '11:30:00',
#   '2019-12-19T00:00:00',
#   '11:35:00',
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '105',
#   'FELONY',
#   None,
#   'ROBBERY',
#   None,
#   'PATROL BORO BRONX',
#   '397.0',
#   'ROBBERY,OPEN AREA UNCLASSIFIED',
#   'STREET',
#   '2019-12-19T00:00:00',
#   None,
#   '25-44',
#   'BLACK',
#   'F',
#   None,
#   '25-44',
#   'BLACK',
#   'M',
#   '1005774',
#   '240846',
#   '40.82772414300007',
#   '-73.92222715099996',
#   [None, '40.82772414300007', '-73.92222715099996', None, False],
#   '10930',
#   '50',
#   '5',
#   '42',
#   '27'],
#  ['row-a648~w4d5-9i7d',
#   '00000000-0000-0000-7240-02862B0CE2EA',
#   0,
#   1579297663,
#   None,
#   1579297841,
#   None,
#   '{ }',
#   '354566222',
#   '42',
#   'BRONX',
#   '2019-12-19T00:00:00',
#   '02:50:00',
#   None,
#   None,
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '104',
#   'FELONY',
#   'INSIDE',
#   'RAPE',
#   None,
#   'PATROL BORO BRONX',
#   '153.0',
#   'RAPE 3',
#   'ABANDONED BUILDING',
#   '2019-12-19T00:00:00',
#   None,
#   '18-24',
#   'BLACK HISPANIC',
#   'M',
#   None,
#   '<18',
#   'BLACK HISPANIC',
#   'F',
#   '1008798',
#   '238971',
#   '40.82256991600008',
#   '-73.91130716899994',
#   [None, '40.82256991600008', '-73.91130716899994', None, False],
#   '10929',
#   '34',
#   '5',
#   '43',
#   '25'],
#  ['row-3fjg~ipv7-9w4e',
#   '00000000-0000-0000-6728-1DEB4E9A6660',
#   0,
#   1579297663,
#   None,
#   1579297841,
#   None,
#   '{ }',
#   '394219213',
#   '46',
#   'BRONX',
#   '2019-12-18T00:00:00',
#   '21:45:00',
#   None,
#   None,
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '109',
#   'FELONY',
#   'FRONT OF',
#   'GRAND LARCENY',
#   None,
#   'PATROL BORO BRONX',
#   '443.0',
#   'LARCENY,GRAND OF BICYCLE',
#   'RESTAURANT/DINER',
#   '2019-12-18T00:00:00',
#   None,
#   None,
#   None,
#   None,
#   None,
#   '25-44',
#   'WHITE HISPANIC',
#   'M',
#   '1011779',
#   '251282',
#   '40.85635122700006',
#   '-73.90048600699998',
#   [None, '40.85635122700006', '-73.90048600699998', None, False],
#   '10935',
#   '6',
#   '5',
#   '22',
#   '29'],
#  ['row-vfwc.ufxi~afdu',
#   '00000000-0000-0000-88B8-EF5B75D34153',
#   0,
#   1579297663,
#   None,
#   1579297841,
#   None,
#   '{ }',
#   '406634172',
#   '43',
#   'BRONX',
#   '2019-12-18T00:00:00',
#   '13:20:00',
#   None,
#   None,
#   'ATTEMPTED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '105',
#   'FELONY',
#   None,
#   'ROBBERY',
#   None,
#   'PATROL BORO BRONX',
#   '397.0',
#   'ROBBERY,OPEN AREA UNCLASSIFIED',
#   'STREET',
#   '2019-12-18T00:00:00',
#   None,
#   'UNKNOWN',
#   'UNKNOWN',
#   'U',
#   None,
#   '18-24',
#   'BLACK',
#   'M',
#   '1023078',
#   '240343',
#   '40.82628443600004',
#   '-73.85970428899996',
#   [None, '40.82628443600004', '-73.85970428899996', None, False],
#   '11611',
#   '58',
#   '5',
#   '31',
#   '26'],
#  ['row-5juf.36nw.x8rr',
#   '00000000-0000-0000-E632-BAF4283F2894',
#   0,
#   1579297663,
#   None,
#   1579297841,
#   None,
#   '{ }',
#   '610332477',
#   '113',
#   'QUEENS',
#   '2019-12-17T00:00:00',
#   '14:30:00',
#   '2019-12-17T00:00:00',
#   '14:35:00',
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '578',
#   'VIOLATION',
#   None,
#   'HARRASSMENT 2',
#   None,
#   'PATROL BORO QUEENS SOUTH',
#   '638.0',
#   'HARASSMENT,SUBD 3,4,5',
#   'STREET',
#   '2019-12-17T00:00:00',
#   None,
#   None,
#   None,
#   None,
#   None,
#   '<18',
#   'BLACK HISPANIC',
#   'M',
#   '1044336',
#   '191327',
#   '40.691629445000046',
#   '-73.78333111099995',
#   [None, '40.691629445000046', '-73.78333111099995', None, False],
#   '24668',
#   '41',
#   '3',
#   '6',
#   '71'],
#  ['row-8s4k~dcd7~x7ug',
#   '00000000-0000-0000-BC5C-9BDC887C1C05',
#   0,
#   1579297663,
#   None,
#   1579297841,
#   None,
#   '{ }',
#   '727608720',
#   '10',
#   'MANHATTAN',
#   '2019-12-17T00:00:00',
#   '09:40:00',
#   None,
#   None,
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '578',
#   'VIOLATION',
#   None,
#   'HARRASSMENT 2',
#   None,
#   'PATROL BORO MAN SOUTH',
#   '638.0',
#   'HARASSMENT,SUBD 3,4,5',
#   'STREET',
#   '2019-12-17T00:00:00',
#   None,
#   '25-44',
#   'BLACK',
#   'M',
#   None,
#   '18-24',
#   'WHITE',
#   'F',
#   '984802',
#   '211047',
#   '40.74596005300003',
#   '-73.99800931399994',
#   [None, '40.74596005300003', '-73.99800931399994', None, False],
#   '12074',
#   '12',
#   '4',
#   '10',
#   '6'],
#  ['row-4ckd~tbzn~c9tf',
#   '00000000-0000-0000-EFA4-DDBE1A8E571C',
#   0,
#   1579297663,
#   None,
#   1579297841,
#   None,
#   '{ }',
#   '420183118',
#   '45',
#   'BRONX',
#   '2019-12-17T00:00:00',
#   '04:00:00',
#   '2019-12-17T00:00:00',
#   '07:00:00',
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '110',
#   'FELONY',
#   'FRONT OF',
#   'GRAND LARCENY OF MOTOR VEHICLE',
#   None,
#   'PATROL BORO BRONX',
#   '441.0',
#   'LARCENY,GRAND OF AUTO',
#   'STREET',
#   '2019-12-17T00:00:00',
#   None,
#   None,
#   None,
#   None,
#   None,
#   '65+',
#   'WHITE',
#   'M',
#   '1035262',
#   '245336',
#   '40.83992679200002',
#   '-73.81564200199995',
#   [None, '40.83992679200002', '-73.81564200199995', None, False],
#   '11274',
#   '43',
#   '5',
#   '12',
#   '28'],
#  ['row-k8tq~ywfq.uvqh',
#   '00000000-0000-0000-9CCF-86FEDA6AF9A1',
#   0,
#   1579297663,
#   None,
#   1579297841,
#   None,
#   '{ }',
#   '550070572',
#   '62',
#   'BROOKLYN',
#   '2019-12-16T00:00:00',
#   '18:20:00',
#   '2019-12-16T00:00:00',
#   '18:40:00',
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '578',
#   'VIOLATION',
#   'FRONT OF',
#   'HARRASSMENT 2',
#   None,
#   'PATROL BORO BKLYN SOUTH',
#   '637.0',
#   'HARASSMENT,SUBD 1,CIVILIAN',
#   'STREET',
#   '2019-12-16T00:00:00',
#   None,
#   '25-44',
#   'WHITE',
#   'M',
#   None,
#   '25-44',
#   'WHITE',
#   'F',
#   '981769',
#   '161398',
#   '40.60968444700006',
#   '-74.00893694499997',
#   [None, '40.60968444700006', '-74.00893694499997', None, False],
#   '13511',
#   '1',
#   '2',
#   '44',
#   '37'],
#  ['row-hpgt~7nh8.nhda',
#   '00000000-0000-0000-5A9A-C7F418B014E4',
#   0,
#   1579297663,
#   None,
#   1579297841,
#   None,
#   '{ }',
#   '746410047',
#   '28',
#   'MANHATTAN',
#   '2019-12-16T00:00:00',
#   '15:40:00',
#   '2019-12-16T00:00:00',
#   '15:55:00',
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '344',
#   'MISDEMEANOR',
#   'INSIDE',
#   'ASSAULT 3 & RELATED OFFENSES',
#   None,
#   'PATROL BORO MAN NORTH',
#   '101.0',
#   'ASSAULT 3',
#   'CLOTHING/BOUTIQUE',
#   '2019-12-16T00:00:00',
#   None,
#   '45-64',
#   'BLACK',
#   'U',
#   None,
#   '<18',
#   'WHITE',
#   'F',
#   '997571',
#   '234556',
#   '40.810476043000044',
#   '-73.95188015099995',
#   [None, '40.810476043000044', '-73.95188015099995', None, False],
#   '12424',
#   '18',
#   '4',
#   '36',
#   '18'],
#  ['row-ysar_vvx5-mba8',
#   '00000000-0000-0000-DC30-78B657389E35',
#   0,
#   1579297663,
#   None,
#   1579297841,
#   None,
#   '{ }',
#   '381553349',
#   '43',
#   'BRONX',
#   '2019-12-16T00:00:00',
#   '13:40:00',
#   None,
#   None,
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '344',
#   'MISDEMEANOR',
#   None,
#   'ASSAULT 3 & RELATED OFFENSES',
#   None,
#   'PATROL BORO BRONX',
#   '101.0',
#   'ASSAULT 3',
#   'OTHER',
#   '2019-12-16T00:00:00',
#   None,
#   'UNKNOWN',
#   'UNKNOWN',
#   'U',
#   None,
#   '45-64',
#   'WHITE HISPANIC',
#   'M',
#   '1022239',
#   '242799',
#   '40.83302909400004',
#   '-73.86272193399996',
#   [None, '40.83302909400004', '-73.86272193399996', None, False],
#   '11610',
#   '58',
#   '5',
#   '31',
#   '26'],
#  ['row-4ssk.ev7b-j4kf',
#   '00000000-0000-0000-1299-E51E614E9FF8',
#   0,
#   1579297663,
#   None,
#   1579297841,
#   None,
#   '{ }',
#   '628600144',
#   '43',
#   'BRONX',
#   '2019-12-16T00:00:00',
#   '11:10:00',
#   None,
#   None,
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '348',
#   'MISDEMEANOR',
#   None,
#   'VEHICLE AND TRAFFIC LAWS',
#   None,
#   'PATROL BORO BRONX',
#   '916.0',
#   'LEAVING SCENE-ACCIDENT-PERSONA',
#   'STREET',
#   '2019-12-16T00:00:00',
#   None,
#   'UNKNOWN',
#   'UNKNOWN',
#   'U',
#   None,
#   '45-64',
#   'BLACK',
#   'M',
#   '1025754',
#   '240828',
#   '40.82760345200006',
#   '-73.85003211999998',
#   [None, '40.82760345200006', '-73.85003211999998', None, False],
#   '11610',
#   '58',
#   '5',
#   '31',
#   '26'],
#  ['row-8xnj-4zkz~ar8j',
#   '00000000-0000-0000-99C0-E124961DA5DC',
#   0,
#   1579297663,
#   None,
#   1579297841,
#   None,
#   '{ }',
#   '365743338',
#   '75',
#   'BROOKLYN',
#   '2019-12-16T00:00:00',
#   '01:00:00',
#   None,
#   None,
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '341',
#   'MISDEMEANOR',
#   None,
#   'PETIT LARCENY',
#   None,
#   'PATROL BORO BKLYN NORTH',
#   '321.0',
#   'LARCENY,PETIT FROM AUTO',
#   'STREET',
#   '2019-12-16T00:00:00',
#   None,
#   None,
#   None,
#   None,
#   None,
#   '25-44',
#   'UNKNOWN',
#   'F',
#   '1018987',
#   '183104',
#   '40.66919498800007',
#   '-73.87478191299994',
#   [None, '40.66919498800007', '-73.87478191299994', None, False],
#   '17215',
#   '45',
#   '2',
#   '25',
#   '47'],
#  ['row-8cqi_tjzp~ymse',
#   '00000000-0000-0000-5664-3F9739040F8C',
#   0,
#   1579297663,
#   None,
#   1579297841,
#   None,
#   '{ }',
#   '484817313',
#   '42',
#   'BRONX',
#   '2019-12-15T00:00:00',
#   '21:30:00',
#   '2019-12-15T00:00:00',
#   '22:30:00',
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '341',
#   'MISDEMEANOR',
#   'INSIDE',
#   'PETIT LARCENY',
#   None,
#   'PATROL BORO BRONX',
#   '321.0',
#   'LARCENY,PETIT FROM AUTO',
#   'STREET',
#   '2019-12-16T00:00:00',
#   None,
#   'UNKNOWN',
#   'UNKNOWN',
#   'U',
#   None,
#   '25-44',
#   'BLACK',
#   'F',
#   '1014901',
#   '243467',
#   '40.83489107400004',
#   '-73.88923592399993',
#   [None, '40.83489107400004', '-73.88923592399993', None, False],
#   '11269',
#   '34',
#   '5',
#   '43',
#   '25'],
#  ['row-m7kf-fq9g~8whg',
#   '00000000-0000-0000-E7E3-8F44A4282234',
#   0,
#   1579297663,
#   None,
#   1579297841,
#   None,
#   '{ }',
#   '748085703',
#   '111',
#   'QUEENS',
#   '2019-11-29T00:00:00',
#   '12:00:00',
#   None,
#   None,
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '112',
#   'FELONY',
#   'FRONT OF',
#   'THEFT-FRAUD',
#   None,
#   'PATROL BORO QUEENS NORTH',
#   '739.0',
#   'FRAUD,UNCLASSIFIED-FELONY',
#   'RESIDENCE-HOUSE',
#   '2019-12-16T00:00:00',
#   None,
#   None,
#   None,
#   None,
#   None,
#   '25-44',
#   'ASIAN / PACIFIC ISLANDER',
#   'F',
#   '1043973',
#   '209900',
#   '40.742610187000025',
#   '-73.78447530299998',
#   [None, '40.742610187000025', '-73.78447530299998', None, False],
#   '14507',
#   '26',
#   '3',
#   '3',
#   '69'],
#  ['row-bhbd_qvnw.p7wp',
#   '00000000-0000-0000-2EFC-5F92E3116401',
#   0,
#   1579297663,
#   None,
#   1579297841,
#   None,
#   '{ }',
#   '588816147',
#   '52',
#   'BRONX',
#   '2019-12-15T00:00:00',
#   '15:59:00',
#   None,
#   None,
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '578',
#   'VIOLATION',
#   'INSIDE',
#   'HARRASSMENT 2',
#   None,
#   'PATROL BORO BRONX',
#   '637.0',
#   'HARASSMENT,SUBD 1,CIVILIAN',
#   'FAST FOOD',
#   '2019-12-15T00:00:00',
#   None,
#   'UNKNOWN',
#   'UNKNOWN',
#   'F',
#   None,
#   '45-64',
#   'BLACK',
#   'F',
#   '1011134',
#   '253597',
#   '40.86270719100002',
#   '-73.90280835099996',
#   [None, '40.86270719100002', '-73.90280835099996', None, False],
#   '11606',
#   '24',
#   '5',
#   '29',
#   '34'],
#  ['row-r7uj_t62x_5jtf',
#   '00000000-0000-0000-FC00-F120DCA66498',
#   0,
#   1579297663,
#   None,
#   1579297841,
#   None,
#   '{ }',
#   '387676075',
#   '43',
#   'BRONX',
#   '2019-12-14T00:00:00',
#   '23:35:00',
#   None,
#   None,
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '344',
#   'MISDEMEANOR',
#   'INSIDE',
#   'ASSAULT 3 & RELATED OFFENSES',
#   None,
#   'PATROL BORO BRONX',
#   '101.0',
#   'ASSAULT 3',
#   'RESIDENCE - APT. HOUSE',
#   '2019-12-15T00:00:00',
#   None,
#   'UNKNOWN',
#   'WHITE',
#   'M',
#   None,
#   '25-44',
#   'WHITE HISPANIC',
#   'F',
#   '1025401',
#   '242799',
#   '40.83301492700008',
#   '-73.85129554699995',
#   [None, '40.83301492700008', '-73.85129554699995', None, False],
#   '11271',
#   '58',
#   '5',
#   '31',
#   '26'],
#  ['row-hm2t_9xmg-b8xm',
#   '00000000-0000-0000-3E34-4587CF83BC52',
#   0,
#   1579297663,
#   None,
#   1579297841,
#   None,
#   '{ }',
#   '894822342',
#   '43',
#   'BRONX',
#   '2019-12-14T00:00:00',
#   '20:05:00',
#   None,
#   None,
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '578',
#   'VIOLATION',
#   'FRONT OF',
#   'HARRASSMENT 2',
#   None,
#   'PATROL BORO BRONX',
#   '637.0',
#   'HARASSMENT,SUBD 1,CIVILIAN',
#   'STREET',
#   '2019-12-14T00:00:00',
#   None,
#   '25-44',
#   'UNKNOWN',
#   'M',
#   None,
#   '18-24',
#   'UNKNOWN',
#   'M',
#   '1023574',
#   '245286',
#   '40.83984933800008',
#   '-73.85788311899995',
#   [None, '40.83984933800008', '-73.85788311899995', None, False],
#   '11271',
#   '58',
#   '5',
#   '31',
#   '26'],
#  ['row-rbxw.nnrm_dx2f',
#   '00000000-0000-0000-01D6-CE70C5EBBCE6',
#   0,
#   1579297663,
#   None,
#   1579297841,
#   None,
#   '{ }',
#   '405472536',
#   '42',
#   'BRONX',
#   '2019-12-14T00:00:00',
#   '17:13:00',
#   None,
#   None,
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '341',
#   'MISDEMEANOR',
#   'FRONT OF',
#   'PETIT LARCENY',
#   None,
#   'PATROL BORO BRONX',
#   '321.0',
#   'LARCENY,PETIT FROM AUTO',
#   'STREET',
#   '2019-12-14T00:00:00',
#   None,
#   None,
#   None,
#   None,
#   None,
#   '45-64',
#   'BLACK',
#   'M',
#   '1011674',
#   '243887',
#   '40.83605446300004',
#   '-73.90089581899997',
#   [None, '40.83605446300004', '-73.90089581899997', None, False],
#   '10934',
#   '34',
#   '5',
#   '42',
#   '25'],
#  ['row-f4qq_2grm.4w4x',
#   '00000000-0000-0000-493E-F62932E1B239',
#   0,
#   1579297663,
#   None,
#   1579297841,
#   None,
#   '{ }',
#   '613588144',
#   '67',
#   'BROOKLYN',
#   '2019-12-13T00:00:00',
#   '20:00:00',
#   '2019-12-13T00:00:00',
#   '20:10:00',
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '235',
#   'MISDEMEANOR',
#   'FRONT OF',
#   'DANGEROUS DRUGS',
#   None,
#   'PATROL BORO BKLYN SOUTH',
#   '569.0',
#   'MARIJUANA, SALE 4 & 5',
#   'STREET',
#   '2019-12-13T00:00:00',
#   None,
#   '18-24',
#   'BLACK',
#   'M',
#   None,
#   'UNKNOWN',
#   'UNKNOWN',
#   'E',
#   '998645',
#   '176413',
#   '40.650886108000066',
#   '-73.94812476999994',
#   [None, '40.650886108000066', '-73.94812476999994', None, False],
#   '13510',
#   '61',
#   '2',
#   '11',
#   '40'],
#  ['row-mz8q-j27z.m2yx',
#   '00000000-0000-0000-BB6C-508AB6108C6B',
#   0,
#   1579297663,
#   None,
#   1579297984,
#   None,
#   '{ }',
#   '393397086',
#   '109',
#   'QUEENS',
#   '2019-07-06T00:00:00',
#   '02:27:00',
#   '2019-07-07T00:00:00',
#   '02:30:00',
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '341',
#   'MISDEMEANOR',
#   'FRONT OF',
#   'PETIT LARCENY',
#   None,
#   'PATROL BORO QUEENS NORTH',
#   '321.0',
#   'LARCENY,PETIT FROM AUTO',
#   'STREET',
#   '2019-07-07T00:00:00',
#   None,
#   None,
#   None,
#   None,
#   None,
#   '65+',
#   'WHITE',
#   'M',
#   '1040517',
#   '215131',
#   '40.75699059000005',
#   '-73.79690337399995',
#   [None, '40.75699059000005', '-73.79690337399995', None, False],
#   '14193',
#   '22',
#   '3',
#   '20',
#   '67'],
#  ['row-uu8s~m6w5-j8aa',
#   '00000000-0000-0000-4C61-57A93CE9C0CA',
#   0,
#   1579297663,
#   None,
#   1579297841,
#   None,
#   '{ }',
#   '117797339',
#   '17',
#   'MANHATTAN',
#   '2019-12-11T00:00:00',
#   '23:20:00',
#   '2019-12-11T00:00:00',
#   '23:35:00',
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '106',
#   'FELONY',
#   'FRONT OF',
#   'FELONY ASSAULT',
#   None,
#   'PATROL BORO MAN SOUTH',
#   '109.0',
#   'ASSAULT 2,1,UNCLASSIFIED',
#   'STREET',
#   '2019-12-12T00:00:00',
#   None,
#   'UNKNOWN',
#   'UNKNOWN',
#   'F',
#   None,
#   '18-24',
#   'WHITE',
#   'F',
#   '992381',
#   '215224',
#   '40.757421143000045',
#   '-73.97065210199997',
#   [None, '40.757421143000045', '-73.97065210199997', None, False],
#   '12419',
#   '71',
#   '4',
#   '51',
#   '9'],
#  ['row-5wii_am7i.wyay',
#   '00000000-0000-0000-EF1D-31646044F614',
#   0,
#   1579297663,
#   None,
#   1579297841,
#   None,
#   '{ }',
#   '160710601',
#   '70',
#   'BROOKLYN',
#   '2019-12-04T00:00:00',
#   '14:30:00',
#   None,
#   None,
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '341',
#   'MISDEMEANOR',
#   'INSIDE',
#   'PETIT LARCENY',
#   None,
#   'PATROL BORO BKLYN SOUTH',
#   '352.0',
#   'LARCENY,PETIT FROM BUILDING,UNATTENDED, PACKAGE THEFT INSIDE',
#   'RESIDENCE-HOUSE',
#   '2019-12-12T00:00:00',
#   None,
#   None,
#   None,
#   None,
#   None,
#   '45-64',
#   'WHITE',
#   'M',
#   '998909',
#   '166286',
#   '40.62308921900007',
#   '-73.94719536699995',
#   [None, '40.62308921900007', '-73.94719536699995', None, False],
#   '17217',
#   '60',
#   '2',
#   '26',
#   '43'],
#  ['row-59m5-bxbf-ievb',
#   '00000000-0000-0000-FD6F-C9E0DE41E8CF',
#   0,
#   1579297663,
#   None,
#   1579297841,
#   None,
#   '{ }',
#   '623322570',
#   '68',
#   'BROOKLYN',
#   '2019-12-11T00:00:00',
#   '21:17:00',
#   '2019-12-11T00:00:00',
#   '21:17:00',
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '233',
#   'MISDEMEANOR',
#   'FRONT OF',
#   'SEX CRIMES',
#   None,
#   'PATROL BORO BKLYN SOUTH',
#   '681.0',
#   'CHILD, ENDANGERING WELFARE',
#   'STREET',
#   '2019-12-11T00:00:00',
#   None,
#   'UNKNOWN',
#   'WHITE',
#   'M',
#   None,
#   '<18',
#   'WHITE',
#   'F',
#   '978016',
#   '172087',
#   '40.63902167200007',
#   '-74.022463524',
#   [None, '40.63902167200007', '-74.022463524', None, False],
#   '18180',
#   '10',
#   '2',
#   '7',
#   '41'],
#  ['row-raat-xymh~ftfj',
#   '00000000-0000-0000-CC9B-7C324455BA75',
#   0,
#   1579297663,
#   None,
#   1579297841,
#   None,
#   '{ }',
#   '826151049',
#   '47',
#   'BRONX',
#   '2019-12-11T00:00:00',
#   '16:10:00',
#   None,
#   None,
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '344',
#   'MISDEMEANOR',
#   'INSIDE',
#   'ASSAULT 3 & RELATED OFFENSES',
#   None,
#   'PATROL BORO BRONX',
#   '101.0',
#   'ASSAULT 3',
#   'RESIDENCE - APT. HOUSE',
#   '2019-12-11T00:00:00',
#   None,
#   '<18',
#   'BLACK',
#   'M',
#   None,
#   '45-64',
#   'BLACK',
#   'M',
#   '1021522',
#   '256468',
#   '40.87054946000006',
#   '-73.86523693899994',
#   [None, '40.87054946000006', '-73.86523693899994', None, False],
#   '11605',
#   '29',
#   '5',
#   '22',
#   '30'],
#  ['row-nirt~kfy4~pvzh',
#   '00000000-0000-0000-C3E8-AB8232DDB900',
#   0,
#   1579297663,
#   None,
#   1579297841,
#   None,
#   '{ }',
#   '626711234',
#   '44',
#   'BRONX',
#   '2019-12-11T00:00:00',
#   '15:20:00',
#   None,
#   None,
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '341',
#   'MISDEMEANOR',
#   'FRONT OF',
#   'PETIT LARCENY',
#   None,
#   'PATROL BORO BRONX',
#   '321.0',
#   'LARCENY,PETIT FROM AUTO',
#   'STREET',
#   '2019-12-11T00:00:00',
#   None,
#   None,
#   None,
#   None,
#   None,
#   '45-64',
#   'BLACK',
#   'M',
#   '1005391',
#   '245671',
#   '40.840968298000064',
#   '-73.92359586699997',
#   [None, '40.840968298000064', '-73.92359586699997', None, False],
#   '10930',
#   '50',
#   '5',
#   '42',
#   '27'],
#  ['row-gvrq-4aaw~ifmn',
#   '00000000-0000-0000-3B20-B174A586BD31',
#   0,
#   1579297663,
#   None,
#   1579297841,
#   None,
#   '{ }',
#   '211421210',
#   '71',
#   'BROOKLYN',
#   '2019-12-11T00:00:00',
#   '11:00:00',
#   None,
#   None,
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '116',
#   'FELONY',
#   'INSIDE',
#   'SEX CRIMES',
#   None,
#   'PATROL BORO BKLYN SOUTH',
#   '177.0',
#   'SEXUAL ABUSE',
#   None,
#   '2019-12-11T00:00:00',
#   None,
#   None,
#   None,
#   None,
#   None,
#   '<18',
#   'BLACK',
#   'M',
#   '998749',
#   '181383',
#   '40.66452749800004',
#   '-73.94773929099993',
#   [None, '40.66452749800004', '-73.94773929099993', None, False],
#   '13509',
#   '17',
#   '2',
#   '48',
#   '44'],
#  ['row-krm7.6q4j-pcbt',
#   '00000000-0000-0000-9934-AF9F39F25DE5',
#   0,
#   1579297663,
#   None,
#   1579297841,
#   None,
#   '{ }',
#   '673030484',
#   '26',
# ...
#   'RESIDENCE-HOUSE',
#   '2019-04-25T00:00:00',
#   None,
#   None,
#   None,
#   None,
#   None,
#   '45-64',
#   'WHITE',
#   'F',
#   '939677',
#   '134840',
#   '40.53667628400007',
#   '-74.16035909999994',
#   [None, '40.53667628400007', '-74.16035909999994', None, False],
#   '10699',
#   '15',
#   '1',
#   '9',
#   '77'],
#  ['row-ywst~hpye.is9s',
#   '00000000-0000-0000-4EEB-2CBE09921B16',
#   0,
#   1579297663,
#   None,
#   1579297951,
#   None,
#   '{ }',
#   '911964758',
#   '6',
#   'MANHATTAN',
#   '2019-08-08T00:00:00',
#   '18:25:00',
#   '2019-08-08T00:00:00',
#   '18:26:00',
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '578',
#   'VIOLATION',
#   None,
#   'HARRASSMENT 2',
#   None,
#   'PATROL BORO MAN SOUTH',
#   '638.0',
#   'HARASSMENT,SUBD 3,4,5',
#   'STREET',
#   '2019-08-08T00:00:00',
#   None,
#   'UNKNOWN',
#   'UNKNOWN',
#   'U',
#   None,
#   '25-44',
#   'WHITE',
#   'M',
#   '983065',
#   '206471',
#   '40.73340000400003',
#   '-74.00427723599995',
#   [None, '40.73340000400003', '-74.00427723599995', None, False],
#   '12077',
#   '57',
#   '4',
#   '10',
#   '3'],
#  ['row-k66j.dsnj~mgq8',
#   '00000000-0000-0000-DC03-836D5C517F2A',
#   0,
#   1579297663,
#   None,
#   1579298048,
#   None,
#   '{ }',
#   '499472710',
#   '72',
#   'BROOKLYN',
#   '2019-04-24T00:00:00',
#   '21:00:00',
#   None,
#   None,
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '578',
#   'VIOLATION',
#   'FRONT OF',
#   'HARRASSMENT 2',
#   None,
#   'PATROL BORO BKLYN SOUTH',
#   '638.0',
#   'HARASSMENT,SUBD 3,4,5',
#   'OTHER',
#   '2019-04-24T00:00:00',
#   None,
#   '25-44',
#   'UNKNOWN',
#   'M',
#   None,
#   '45-64',
#   'WHITE',
#   'F',
#   '981460',
#   '171258',
#   '40.63674799800003',
#   '-74.01005390799997',
#   [None, '40.63674799800003', '-74.01005390799997', None, False],
#   '18180',
#   '9',
#   '2',
#   '7',
#   '45'],
#  ['row-ppmc_jbid~evrj',
#   '00000000-0000-0000-BE2A-CA1D246E71DF',
#   0,
#   1579297663,
#   None,
#   1579297951,
#   None,
#   '{ }',
#   '498171744',
#   '67',
#   'BROOKLYN',
#   '2019-08-06T00:00:00',
#   '15:05:00',
#   '2019-08-06T00:00:00',
#   '15:13:00',
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '117',
#   'FELONY',
#   None,
#   'DANGEROUS DRUGS',
#   None,
#   'PATROL BORO BKLYN SOUTH',
#   '503.0',
#   'CONTROLLED SUBSTANCE,INTENT TO',
#   'STREET',
#   '2019-08-06T00:00:00',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'UNKNOWN',
#   'UNKNOWN',
#   'E',
#   '1007465',
#   '177970',
#   '40.655141005000075',
#   '-73.91633392699998',
#   [None, '40.655141005000075', '-73.91633392699998', None, False],
#   '17614',
#   '61',
#   '2',
#   '25',
#   '40'],
#  ['row-t4q2-dpcg.nuhc',
#   '00000000-0000-0000-50BA-AB71660AFFA5',
#   0,
#   1579297663,
#   None,
#   1579297951,
#   None,
#   '{ }',
#   '886800946',
#   '25',
#   'MANHATTAN',
#   '2019-08-04T00:00:00',
#   '16:01:00',
#   None,
#   None,
#   'COMPLETED',
#   None,
#   None,
#   '11.0',
#   'N.Y. STATE POLICE',
#   '117',
#   'FELONY',
#   'INSIDE',
#   'DANGEROUS DRUGS',
#   None,
#   'PATROL BORO MAN NORTH',
#   '501.0',
#   'CONTROLLED SUBSTANCE,POSSESS.',
#   'BRIDGE',
#   '2019-08-04T00:00:00',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'UNKNOWN',
#   'UNKNOWN',
#   'E',
#   '1004138',
#   '226326',
#   '40.78787459900008',
#   '-73.92818164599998',
#   [None, '40.78787459900008', '-73.92818164599998', None, False],
#   '13093',
#   '7',
#   '4',
#   '35',
#   '16'],
#  ['row-zu9g~ggwe-cxec',
#   '00000000-0000-0000-A74F-46C6A048B870',
#   0,
#   1579297663,
#   None,
#   1579297951,
#   None,
#   '{ }',
#   '388694882',
#   '73',
#   'BROOKLYN',
#   '2019-08-10T00:00:00',
#   '00:50:00',
#   '2019-08-10T00:00:00',
#   '01:00:00',
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '126',
#   'FELONY',
#   None,
#   'MISCELLANEOUS PENAL LAW',
#   None,
#   'PATROL BORO BKLYN NORTH',
#   '117.0',
#   'RECKLESS ENDANGERMENT 1',
#   'STREET',
#   '2019-08-10T00:00:00',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'UNKNOWN',
#   'UNKNOWN',
#   'E',
#   '1006499',
#   '183702',
#   '40.67087655300003',
#   '-73.91979650299999',
#   [None, '40.67087655300003', '-73.91979650299999', None, False],
#   '13516',
#   '55',
#   '2',
#   '17',
#   '46'],
#  ['row-myy8~vpur_rhmt',
#   '00000000-0000-0000-F59D-3A8982E4FB57',
#   0,
#   1579297663,
#   None,
#   1579297951,
#   None,
#   '{ }',
#   '904258275',
#   '34',
#   'MANHATTAN',
#   '2019-08-12T00:00:00',
#   '07:00:00',
#   '2019-08-12T00:00:00',
#   '07:05:00',
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '341',
#   'MISDEMEANOR',
#   None,
#   'PETIT LARCENY',
#   None,
#   'PATROL BORO MAN NORTH',
#   '321.0',
#   'LARCENY,PETIT FROM AUTO',
#   'STREET',
#   '2019-08-12T00:00:00',
#   None,
#   None,
#   None,
#   None,
#   None,
#   '25-44',
#   'WHITE HISPANIC',
#   'M',
#   '1004103',
#   '251575',
#   '40.857176021000036',
#   '-73.92823333899997',
#   [None, '40.857176021000036', '-73.92823333899997', None, False],
#   '13098',
#   '47',
#   '4',
#   '39',
#   '22'],
#  ['row-cgd3_vp3p.zbcz',
#   '00000000-0000-0000-D457-73D4FC615989',
#   0,
#   1579297663,
#   None,
#   1579298048,
#   None,
#   '{ }',
#   '415531981',
#   '44',
#   'BRONX',
#   '2019-04-23T00:00:00',
#   '15:58:00',
#   None,
#   None,
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '348',
#   'MISDEMEANOR',
#   None,
#   'VEHICLE AND TRAFFIC LAWS',
#   None,
#   'PATROL BORO BRONX',
#   '916.0',
#   'LEAVING SCENE-ACCIDENT-PERSONA',
#   'STREET',
#   '2019-04-23T00:00:00',
#   None,
#   None,
#   None,
#   None,
#   None,
#   '25-44',
#   'BLACK',
#   'M',
#   '1006875',
#   '242707',
#   '40.83282930100006',
#   '-73.91824255099993',
#   [None, '40.83282930100006', '-73.91824255099993', None, False],
#   '10934',
#   '50',
#   '5',
#   '42',
#   '27'],
#  ['row-p9qv-ysb9-mqmc',
#   '00000000-0000-0000-C458-1AC3A11B0D3A',
#   0,
#   1579297663,
#   None,
#   1579297951,
#   None,
#   '{ }',
#   '568333959',
#   '90',
#   'BROOKLYN',
#   '2019-08-08T00:00:00',
#   '04:20:00',
#   '2019-08-08T00:00:00',
#   '04:25:00',
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '109',
#   'FELONY',
#   None,
#   'GRAND LARCENY',
#   None,
#   'PATROL BORO BKLYN NORTH',
#   '443.0',
#   'LARCENY,GRAND OF BICYCLE',
#   'STREET',
#   '2019-08-08T00:00:00',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'UNKNOWN',
#   'UNKNOWN',
#   'D',
#   '1001658',
#   '197989',
#   '40.710101916000035',
#   '-73.93721079799997',
#   [None, '40.710101916000035', '-73.93721079799997', None, False],
#   '17213',
#   '36',
#   '2',
#   '30',
#   '56'],
#  ['row-mh8h_f73h.ra4u',
#   '00000000-0000-0000-008D-2B4AB4737075',
#   0,
#   1579297663,
#   None,
#   1579298048,
#   None,
#   '{ }',
#   '709113936',
#   '43',
#   'BRONX',
#   '2019-04-23T00:00:00',
#   '00:01:00',
#   None,
#   None,
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '105',
#   'FELONY',
#   None,
#   'ROBBERY',
#   None,
#   'PATROL BORO BRONX',
#   '386.0',
#   'ROBBERY,PERSONAL ELECTRONIC DEVICE',
#   'STREET',
#   '2019-04-23T00:00:00',
#   None,
#   'UNKNOWN',
#   'UNKNOWN',
#   'U',
#   None,
#   '25-44',
#   'BLACK',
#   'M',
#   '1020846',
#   '241582',
#   '40.82969466400005',
#   '-73.86776240099994',
#   [None, '40.82969466400005', '-73.86776240099994', None, False],
#   '11610',
#   '58',
#   '5',
#   '31',
#   '26'],
#  ['row-78vc-2hcs.jv5q',
#   '00000000-0000-0000-AEE2-F1ADE3D32C95',
#   0,
#   1579297663,
#   None,
#   1579297951,
#   None,
#   '{ }',
#   '334194279',
#   '63',
#   'BROOKLYN',
#   '2018-02-15T00:00:00',
#   '23:00:00',
#   '2018-02-16T00:00:00',
#   '00:00:00',
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '104',
#   'FELONY',
#   'INSIDE',
#   'RAPE',
#   None,
#   'PATROL BORO BKLYN SOUTH',
#   '157.0',
#   'RAPE 1',
#   'HOTEL/MOTEL',
#   '2019-08-12T00:00:00',
#   None,
#   '25-44',
#   'BLACK',
#   'M',
#   None,
#   '25-44',
#   'BLACK',
#   'F',
#   '1000448',
#   '168068',
#   '40.627977755000074',
#   '-73.94164715699996',
#   [None, '40.627977755000074', '-73.94164715699996', None, False],
#   '17217',
#   '5',
#   '2',
#   '26',
#   '38'],
#  ['row-n8j5~iecz-bzhx',
#   '00000000-0000-0000-C9AC-271F2C5FF284',
#   0,
#   1579297663,
#   None,
#   1579297951,
#   None,
#   '{ }',
#   '669659878',
#   '50',
#   'BRONX',
#   '2019-08-08T00:00:00',
#   '17:00:00',
#   None,
#   None,
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '578',
#   'VIOLATION',
#   'FRONT OF',
#   'HARRASSMENT 2',
#   None,
#   'PATROL BORO BRONX',
#   '637.0',
#   'HARASSMENT,SUBD 1,CIVILIAN',
#   'STREET',
#   '2019-08-08T00:00:00',
#   None,
#   '25-44',
#   'BLACK',
#   'F',
#   None,
#   '25-44',
#   'BLACK',
#   'M',
#   '1011228',
#   '257997',
#   '40.87478355800005',
#   '-73.90245080199998',
#   [None, '40.87478355800005', '-73.90245080199998', None, False],
#   '11272',
#   '48',
#   '5',
#   '29',
#   '33'],
#  ['row-gakw_xr9a_rfkc',
#   '00000000-0000-0000-ED57-FFB8FFD11C6F',
#   0,
#   1579297663,
#   None,
#   1579298048,
#   None,
#   '{ }',
#   '684174918',
#   '40',
#   'BRONX',
#   '2019-04-22T00:00:00',
#   '15:30:00',
#   '2019-04-22T00:00:00',
#   '15:50:00',
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '109',
#   'FELONY',
#   'FRONT OF',
#   'GRAND LARCENY',
#   None,
#   'PATROL BORO BRONX',
#   '415.0',
#   'LARCENY,GRAND FROM PERSON,PICK',
#   'STREET',
#   '2019-04-22T00:00:00',
#   None,
#   None,
#   None,
#   None,
#   None,
#   '25-44',
#   'BLACK',
#   'F',
#   '1006763',
#   '236698',
#   '40.81633659300008',
#   '-73.91866744099997',
#   [None, '40.81633659300008', '-73.91866744099997', None, False],
#   '10933',
#   '49',
#   '5',
#   '43',
#   '23'],
#  ['row-5ur5~hpap~jfc5',
#   '00000000-0000-0000-6BC7-435D09A616F4',
#   0,
#   1579297663,
#   None,
#   1579297951,
#   None,
#   '{ }',
#   '535644683',
#   '90',
#   'BROOKLYN',
#   '2019-08-06T00:00:00',
#   '14:50:00',
#   None,
#   None,
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '126',
#   'FELONY',
#   None,
#   'MISCELLANEOUS PENAL LAW',
#   None,
#   'PATROL BORO BKLYN NORTH',
#   '117.0',
#   'RECKLESS ENDANGERMENT 1',
#   'STREET',
#   '2019-08-06T00:00:00',
#   None,
#   '45-64',
#   'WHITE HISPANIC',
#   'M',
#   None,
#   'UNKNOWN',
#   'UNKNOWN',
#   'E',
#   '999333',
#   '198493',
#   '40.71148954500006',
#   '-73.94559593999998',
#   [None, '40.71148954500006', '-73.94559593999998', None, False],
#   '17613',
#   '36',
#   '2',
#   '30',
#   '56'],
#  ['row-c2qc~maaz-t936',
#   '00000000-0000-0000-5000-739FEDA9A188',
#   0,
#   1579297663,
#   None,
#   1579298048,
#   None,
#   '{ }',
#   '892377366',
#   '75',
#   'BROOKLYN',
#   '2019-04-22T00:00:00',
#   '07:00:00',
#   None,
#   None,
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '341',
#   'MISDEMEANOR',
#   'FRONT OF',
#   'PETIT LARCENY',
#   None,
#   'PATROL BORO BKLYN NORTH',
#   '321.0',
#   'LARCENY,PETIT FROM AUTO',
#   'STREET',
#   '2019-04-22T00:00:00',
#   None,
#   None,
#   None,
#   None,
#   None,
#   '25-44',
#   'UNKNOWN',
#   'M',
#   '1015568',
#   '186402',
#   '40.67826000500003',
#   '-73.88709134599996',
#   [None, '40.67826000500003', '-73.88709134599996', None, False],
#   '17214',
#   '45',
#   '2',
#   '37',
#   '47'],
#  ['row-8wye-ctjz_3bvy',
#   '00000000-0000-0000-15A2-A87658407248',
#   0,
#   1579297663,
#   None,
#   1579297935,
#   None,
#   '{ }',
#   '930845062',
#   '103',
#   'QUEENS',
#   '2019-08-31T00:00:00',
#   '14:15:00',
#   '2019-08-31T00:00:00',
#   '14:32:00',
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '341',
#   'MISDEMEANOR',
#   None,
#   'PETIT LARCENY',
#   None,
#   'PATROL BORO QUEENS SOUTH',
#   '313.0',
#   'LARCENY,PETIT BY FALSE PROMISE',
#   'STREET',
#   '2019-08-31T00:00:00',
#   None,
#   'UNKNOWN',
#   'UNKNOWN',
#   'U',
#   None,
#   '18-24',
#   'BLACK',
#   'M',
#   '1040532',
#   '196050',
#   '40.70461795500006',
#   '-73.79700883199997',
#   [None, '40.70461795500006', '-73.79700883199997', None, False],
#   '24340',
#   '41',
#   '3',
#   '24',
#   '61'],
#  ['row-dfim_a9ef~fuv9',
#   '00000000-0000-0000-8D84-BB441B6D076B',
#   0,
#   1579297663,
#   None,
#   1579298048,
#   None,
#   '{ }',
#   '566709190',
#   '23',
#   'MANHATTAN',
#   '2019-04-21T00:00:00',
#   '16:15:00',
#   None,
#   None,
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '578',
#   'VIOLATION',
#   'INSIDE',
#   'HARRASSMENT 2',
#   None,
#   'PATROL BORO MAN NORTH',
#   '638.0',
#   'HARASSMENT,SUBD 3,4,5',
#   'DRUG STORE',
#   '2019-04-21T00:00:00',
#   None,
#   'UNKNOWN',
#   'BLACK',
#   'M',
#   None,
#   '25-44',
#   'BLACK',
#   'M',
#   '999501',
#   '227549',
#   '40.79124062300008',
#   '-73.94492405899997',
#   [None, '40.79124062300008', '-73.94492405899997', None, False],
#   '12426',
#   '7',
#   '4',
#   '35',
#   '14'],
#  ['row-6v6g~i5k8.388m',
#   '00000000-0000-0000-EC22-E957EE8B93E6',
#   0,
#   1579297663,
#   None,
#   1579297935,
#   None,
#   '{ }',
#   '719710804',
#   '44',
#   'BRONX',
#   '2019-08-22T00:00:00',
#   '19:00:00',
#   '2019-08-23T00:00:00',
#   '06:29:00',
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '109',
#   'FELONY',
#   'FRONT OF',
#   'GRAND LARCENY',
#   None,
#   'PATROL BORO BRONX',
#   '421.0',
#   'LARCENY,GRAND FROM VEHICLE/MOTORCYCLE',
#   'STREET',
#   '2019-08-23T00:00:00',
#   None,
#   None,
#   None,
#   None,
#   None,
#   '45-64',
#   'BLACK',
#   'M',
#   '1006344',
#   '242200',
#   '40.83143907600004',
#   '-73.92016306899995',
#   [None, '40.83143907600004', '-73.92016306899995', None, False],
#   '10930',
#   '50',
#   '5',
#   '42',
#   '27'],
#  ['row-w6k5-mvfx~3d3h',
#   '00000000-0000-0000-5A16-55600CE0187A',
#   0,
#   1579297663,
#   None,
#   1579297935,
#   None,
#   '{ }',
#   '468749615',
#   '18',
#   'MANHATTAN',
#   '2019-08-29T00:00:00',
#   '17:05:00',
#   None,
#   None,
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '109',
#   'FELONY',
#   'INSIDE',
#   'GRAND LARCENY',
#   None,
#   'PATROL BORO MAN SOUTH',
#   '433.0',
#   'LARCENY,GRAND FROM STORE-SHOPL',
#   'DEPARTMENT STORE',
#   '2019-08-29T00:00:00',
#   None,
#   '25-44',
#   'BLACK',
#   'M',
#   None,
#   'UNKNOWN',
#   'UNKNOWN',
#   'D',
#   '990503',
#   '215519',
#   '40.758232371000084',
#   '-73.97743058499998',
#   [None, '40.758232371000084', '-73.97743058499998', None, False],
#   '12082',
#   '11',
#   '4',
#   '51',
#   '10'],
#  ['row-qbxy-ua6u.7h95',
#   '00000000-0000-0000-2C58-9B8D6FD65745',
#   0,
#   1579297663,
#   None,
#   1579297935,
#   None,
#   '{ }',
#   '896363396',
#   '44',
#   'BRONX',
#   '2019-08-21T00:00:00',
#   '02:20:00',
#   None,
#   None,
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '351',
#   'MISDEMEANOR',
#   'OPPOSITE OF',
#   'CRIMINAL MISCHIEF & RELATED OF',
#   None,
#   'PATROL BORO BRONX',
#   '258.0',
#   'CRIMINAL MISCHIEF 4TH, GRAFFIT',
#   'STREET',
#   '2019-08-30T00:00:00',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'UNKNOWN',
#   'UNKNOWN',
#   'E',
#   '1005871',
#   '242674',
#   '40.83274124100007',
#   '-73.92187076299997',
#   [None, '40.83274124100007', '-73.92187076299997', None, False],
#   '10930',
#   '50',
#   '5',
#   '42',
#   '27'],
#  ['row-vu85-ssg2.dbfh',
#   '00000000-0000-0000-AF13-99ADA8DDEB4A',
#   0,
#   1579297663,
#   None,
#   1579298048,
#   None,
#   '{ }',
#   '284371971',
#   '78',
#   'BROOKLYN',
#   '2019-04-19T00:00:00',
#   '00:00:00',
#   None,
#   None,
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '341',
#   'MISDEMEANOR',
#   'INSIDE',
#   'PETIT LARCENY',
#   None,
#   'PATROL BORO BKLYN SOUTH',
#   '338.0',
#   'LARCENY,PETIT FROM BUILDING,UN',
#   'ATM',
#   '2019-04-21T00:00:00',
#   None,
#   None,
#   None,
#   None,
#   None,
#   '45-64',
#   'BLACK',
#   'M',
#   '992112',
#   '185590',
#   '40.676083154000025',
#   '-73.97165768099995',
#   [None, '40.676083154000025', '-73.97165768099995', None, False],
#   '13829',
#   '16',
#   '2',
#   '27',
#   '50'],
#  ['row-28zg.whgk.dk9w',
#   '00000000-0000-0000-44D0-EA5E60EC32FE',
#   0,
#   1579297663,
#   None,
#   1579297935,
#   None,
#   '{ }',
#   '854023973',
#   '52',
#   'BRONX',
#   '2019-08-23T00:00:00',
#   '10:00:00',
#   None,
#   None,
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '341',
#   'MISDEMEANOR',
#   'INSIDE',
#   'PETIT LARCENY',
#   None,
#   'PATROL BORO BRONX',
#   '349.0',
#   'LARCENY,PETIT OF LICENSE PLATE',
#   'STREET',
#   '2019-08-23T00:00:00',
#   None,
#   None,
#   None,
#   None,
#   None,
#   '18-24',
#   'BLACK',
#   'F',
#   '1017440',
#   '256046',
#   '40.86940749200004',
#   '-73.87999831299999',
#   [None, '40.86940749200004', '-73.87999831299999', None, False],
#   '11605',
#   '24',
#   '5',
#   '40',
#   '34'],
#  ['row-9dw2~2hp4~7qky',
#   '00000000-0000-0000-E843-2D8A54990365',
#   0,
#   1579297663,
#   None,
#   1579298048,
#   None,
#   '{ }',
#   '272813893',
#   '105',
#   'QUEENS',
#   '2019-04-20T00:00:00',
#   '09:20:00',
#   None,
#   None,
#   'COMPLETED',
#   None,
#   None,
#   '0.0',
#   'N.Y. POLICE DEPT',
#   '341',
#   'MISDEMEANOR',
#   'FRONT OF',
#   'PETIT LARCENY',
#   None,
#   'PATROL BORO QUEENS SOUTH',
#   '321.0',
#   'LARCENY,PETIT FROM AUTO',
#   'STREET',
#   '2019-04-20T00:00:00',
#   None,
#   'UNKNOWN',
#   'UNKNOWN',
#   'U',
#   None,
#   '45-64',
#   'BLACK',
#   'F',
#   '1052396',
#   '183472',
#   '40.67001094500005',
#   '-73.75434629799997',
#   [None, '40.67001094500005', '-73.75434629799997', None, False],
#   '15313',
#   '63',
#   '3',
#   '47',
#   '63'],
#  ...]

# %%
rows = []
crime_num = len(crime['data'])
for row in range(crime_num):
    rows.append(crime['data'][row][8:-6])
crime_df = pd.DataFrame(rows)

# %%
crime_df.head()
# Out:
#           0          2            13              15                  32  \
# 0  314773184      BRONX       FELONY         ROBBERY  40.838026269000075
# 1  289837961  MANHATTAN  MISDEMEANOR   PETIT LARCENY  40.800334261000046
# 2  535744284   BROOKLYN       FELONY  FELONY ASSAULT   40.66983179600004
# 3  895678119      BRONX  MISDEMEANOR   PETIT LARCENY   40.87367103500002
# 4  299841674  MANHATTAN  MISDEMEANOR   PETIT LARCENY   40.76093528000007
#
#                    33
# 0  -73.88168118799997
# 1  -73.94565697199994
# 2  -73.93937555099996
# 3  -73.90801364899994
# 4  -73.99452906599998

# %%
crime_df = crime_df.iloc[:,[0, 2,13, 15,32,33]]

# %%
crime_df.head(), len(crime_df)
# Out:
# (          0          2            13              15                  32  \
#  0  314773184      BRONX       FELONY         ROBBERY  40.838026269000075
#  1  289837961  MANHATTAN  MISDEMEANOR   PETIT LARCENY  40.800334261000046
#  2  535744284   BROOKLYN       FELONY  FELONY ASSAULT   40.66983179600004
#  3  895678119      BRONX  MISDEMEANOR   PETIT LARCENY   40.87367103500002
#  4  299841674  MANHATTAN  MISDEMEANOR   PETIT LARCENY   40.76093528000007
#
#                     33
#  0  -73.88168118799997
#  1  -73.94565697199994
#  2  -73.93937555099996
#  3  -73.90801364899994
#  4  -73.99452906599998  , 461711)

# %%
crime['data'][0]
# Out:
# ['row-jqjg_evtp-tn4b',
#  '00000000-0000-0000-0620-6B6BF1A1C9F4',
#  0,
#  1579297663,
#  None,
#  1579297833,
#  None,
#  '{ }',
#  '314773184',
#  '48',
#  'BRONX',
#  '2019-12-31T00:00:00',
#  '18:00:00',
#  None,
#  None,
#  'COMPLETED',
#  None,
#  None,
#  '0.0',
#  'N.Y. POLICE DEPT',
#  '105',
#  'FELONY',
#  None,
#  'ROBBERY',
#  None,
#  'PATROL BORO BRONX',
#  '386.0',
#  'ROBBERY,PERSONAL ELECTRONIC DEVICE',
#  'STREET',
#  '2019-12-31T00:00:00',
#  None,
#  'UNKNOWN',
#  'UNKNOWN',
#  'U',
#  None,
#  '45-64',
#  'WHITE HISPANIC',
#  'F',
#  '1016990',
#  '244612',
#  '40.838026269000075',
#  '-73.88168118799997',
#  [None, '40.838026269000075', '-73.88168118799997', None, False],
#  '11269',
#  '35',
#  '5',
#  '43',
#  '31']
